# %% [markdown]
# Creating all pair in (shop_id, item_id) for each date_block_num. And if row has not item_count from origin sales data, item_count will fill 0.

# %%
# coding: utf-8
import os
from itertools import product

import pandas as pd
import numpy as np
import scipy
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn import preprocessing
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from IPython.display import display

from mydatools.features_generate import features_save

% matplotlib inline

# %% [markdown]
# ## Config

# %%
# trn_path = './data/input/train.csv'
tst_path = './data/input/test.csv'
id_col = 'ID'
label_col = 'item_cnt_month'

submission_path = './data/output/submission/stacking_simple.csv'
output_id_col = id_col
output_label_col = label_col

# %% [markdown]
# ## Load Data

# %%
item_cate_df = pd.read_csv('./data/input/item_categories.csv')
item_df = pd.read_csv('./data/input/items.csv')
sales_df = pd.read_csv('./data/input/sales_train.csv')
shop_df = pd.read_csv('./data/input/shops.csv')

# %%
sales_df['revenue'] = sales_df['item_price'] * sales_df['item_cnt_day']
trn_df = sales_df.groupby(['shop_id', 'item_id', 'date_block_num'])['item_cnt_day'].sum().reset_index()
trn_df = trn_df.rename(columns={'item_cnt_day': 'item_cnt_month'})
trn_df['ID'] = 0
# trn_df['ds_type'] = 'trn'

tst_df = pd.read_csv(tst_path)
tst_df['date_block_num'] = 34
tst_df['item_cnt_month'] = 0
# tst_df['ds_type'] = 'tst'

full_df = pd.concat([trn_df, tst_df])
full_df.head()
# Out:
#    ID  date_block_num  item_cnt_month  item_id  shop_id
# 0   0               1            31.0       30        0
# 1   0               1            11.0       31        0
# 2   0               0             6.0       32        0
# 3   0               1            10.0       32        0
# 4   0               0             3.0       33        0

# %% [markdown]
# ## Get grid
#
# (shop_id, item_id) for each date_block_num

# %%
index_cols = ['shop_id', 'item_id', 'date_block_num']
grid = []
for block_num in full_df['date_block_num'].unique():
    cur_shops = full_df.loc[full_df['date_block_num'] == block_num, 'shop_id'].unique()
    cur_items = full_df.loc[full_df['date_block_num'] == block_num, 'item_id'].unique()
    grid.append(np.array(list(product(*[cur_shops, cur_items, [block_num]])), dtype='int32'))

grid = pd.DataFrame(np.vstack(grid), columns=index_cols, dtype=np.int32)

full_df = grid.merge(full_df, how='left', on=index_cols).fillna(0)

# %%
# for dbn in range(0, 34):
#     # create pair in (shop_id, item_id)
#     unique_shop_id = full_df[full_df['date_block_num'] == dbn]['shop_id'].copy().drop_duplicates()
#     unique_item_id = full_df[full_df['date_block_num'] == dbn]['item_id'].copy().drop_duplicates()
#     m_index = pd.MultiIndex.from_product([unique_shop_id, unique_item_id], names=['shop_id', 'item_id'])
#     val_df = pd.DataFrame([], index=m_index).reset_index()
#     val_df['ID'] = 0
#     val_df['date_block_num'] = dbn
# #     # distinguish origin train data
# #     val_df['ds_type'] = 'add_val'
#     # remove pair (shop_id, item_id) exists in full_df
#     origin_33_df = full_df[full_df['date_block_num'] == dbn][['item_id', 'shop_id', 'item_cnt_month']]
#     val_df = val_df.merge(origin_33_df, how='left', on=['item_id', 'shop_id'])
#     val_df = val_df[val_df.item_cnt_month.isnull()]
#     # no item_count then fill 0
#     val_df['item_cnt_month'] = 0

#     # merge to full_df
#     full_df = pd.concat([full_df, val_df])

# %%
full_df = full_df.sort_values(['date_block_num', 'shop_id', 'item_id'])

# %% [markdown]
# ## Features

# %%
feature_columns = []

def add_features(features):
    if not isinstance(features, list):
        features = [features]
    global feature_columns
    feature_columns.extend([f for f in features if f not in feature_columns])
    
def remove_features(features):
    if not isinstance(features, list):
        features = [features]
    global feature_columns
    feature_columns = [f for f in feature_columns if f not in features]

# %% [markdown]
# **shop_id, item_id**

# %%
# add_features(['shop_id', 'item_id'])

# %% [markdown]
# **datetime info**

# %%
full_df['dt_year'] = full_df['date_block_num'] // 12 + 2013
full_df['dt_month'] = full_df['date_block_num'] % 12 + 1
add_features(['dt_year', 'dt_month'])

# %% [markdown]
# **item_df**

# %%
# tfidf item_name
tfidf_model = TfidfVectorizer(max_df=0.95, min_df=3)
tfidf_res = tfidf_model.fit_transform(item_df['item_name'])

# decomposition
dcp_num = 5
dcp_model = TruncatedSVD(dcp_num)
dcp_tfidf_res = dcp_model.fit_transform(tfidf_res)

# add to item_df
item_name_tfidf_dcp_feats = ['item_name_tfidf_dcp_%d'%i for i in range(dcp_num)]
item_df[item_name_tfidf_dcp_feats] = pd.DataFrame(dcp_tfidf_res)

# %%
# item_name's words count
item_df['item_name_words_count'] = item_df['item_name'].map(lambda x: len(x.split(' ')))

# %%
# add to full_df
full_df = full_df.merge(item_df, how='left', on='item_id')

# add feautures
add_features(item_name_tfidf_dcp_feats + ['item_category_id', 'item_name_words_count'])

# %%
sales_df = sales_df.merge(item_df, how='left', on='item_id')

# %% [markdown]
# **mean encoding**

# %%
# global_mean = full_df[full_df['date_block_num'] < 34]['item_cnt_month'].mean()

# def get_aggragation_feature(df, groupby_cols, agg_col, fillna_value):
#     gb = df.groupby(groupby_cols)[agg_col]
#     fname_fmt = '-'.join(groupby_cols+[agg_col]) + ':%s'
#     agg_df = pd.DataFrame({
#             fname_fmt%'mean': gb.mean(),
# #             fname_fmt%'median': gb.median(),
# #             fname_fmt%'max': gb.max(),
# #             fname_fmt%'min': gb.min(),
#         })
    
#     new_df = df.join(agg_df, on=groupby_cols).fillna(fillna_value)
#     return new_df, agg_df.columns.tolist()

# groupby_cols_list = [
#     ['shop_id', 'item_id'],
#     ['shop_id'],
#     ['item_id'],
# #     ['date_block_num'],
# #     ['dt_year'],
# #     ['dt_month'],
# #     ['item_category_id'],
# ]
# for groupby_cols in groupby_cols_list:
#     full_df, new_feats = get_aggragation_feature(full_df, groupby_cols, 'item_cnt_month', global_mean)
#     add_features(new_feats)

# %%
global_mean = full_df[full_df['date_block_num'] < 34]['item_cnt_month'].mean()

mean_encoding_cols_list = [
    ['shop_id', 'item_id'],
    ['shop_id'],
    ['item_id'],
]
get_mean_encoding_feat_name = lambda cols: 'mean_encoding-' + '-'.join(cols)

for cols in mean_encoding_cols_list:
    full_df[get_mean_encoding_feat_name(cols)] = np.nan
    add_features(get_mean_encoding_feat_name(cols))

kf = KFold(5, shuffle=True, random_state=20180717)
for trn_idx, val_idx in kf.split(full_df['item_cnt_month'].values):
    trn_df, val_df = full_df.iloc[trn_idx].copy(), full_df.iloc[val_idx].copy()
    for cols in mean_encoding_cols_list:
        feat_name = get_mean_encoding_feat_name(cols)
        mean_map = trn_df.groupby(cols)['item_cnt_month'].mean()
        val_df[feat_name] = val_df[cols].join(mean_map, how='left', on=cols)['item_cnt_month']
    full_df.iloc[val_idx] = val_df
full_df.fillna(global_mean, inplace=True)

# %% [markdown]
# **lag features**

# %%
# 获取当月的一些数据（然后进行lag）
cur_month_cols_list = [
    ['shop_id'],
    ['item_id'],
    ['shop_id', 'item_id'],
    ['item_category_id'],
    ['shop_id', 'item_category_id'],
]
cur_month_feats = []
for cols in cur_month_cols_list:
    print(cols)
    gb = sales_df.groupby(['date_block_num'] + cols) \
        .agg({'item_cnt_day': 'sum', 'item_price': 'mean'}) \
        .rename(columns={'item_cnt_day': 'target-' + '-'.join(cols),
                         'item_price': 'item_price-' + '-'.join(cols)})
    cur_month_feats += ['target-' + '-'.join(cols), 'item_price-' + '-'.join(cols)]
    full_df = full_df.join(gb, how='left', on=['date_block_num'] + cols).fillna(0)
# Out:
# ['shop_id']
# ['item_id']
# ['shop_id', 'item_id']
# ['item_category_id']
# ['shop_id', 'item_category_id']

# %%
shift_range = [1,2,3,6,12]
shift_features = cur_month_feats

for shift_month in shift_range:
    print(shift_month)
    tmp_df = full_df[['shop_id', 'item_id', 'date_block_num'] + shift_features].copy()
    tmp_df['date_block_num'] = tmp_df['date_block_num'] + shift_month
    for f in shift_features:
        new_f = f + '_lag_' + str(shift_month)
        tmp_df = tmp_df.rename(columns={f: new_f})
        add_features(new_f)
    full_df = full_df.merge(tmp_df, how='left', on=['shop_id', 'item_id', 'date_block_num']).fillna(0)
# Out:
# 1
# 2
# 3
# 6
# 12

# %%
# remove 2013
full_df = full_df[full_df['date_block_num'] > 12]

# %% [markdown]
# **show all features**

# %%
feature_columns
# Out:
# ['dt_year',
#  'dt_month',
#  'item_name_tfidf_dcp_0',
#  'item_name_tfidf_dcp_1',
#  'item_name_tfidf_dcp_2',
#  'item_name_tfidf_dcp_3',
#  'item_name_tfidf_dcp_4',
#  'item_category_id',
#  'item_name_words_count',
#  'mean_encoding-shop_id-item_id',
#  'mean_encoding-shop_id',
#  'mean_encoding-item_id',
#  'target-shop_id_lag_1',
#  'item_price-shop_id_lag_1',
#  'target-item_id_lag_1',
#  'item_price-item_id_lag_1',
#  'target-shop_id-item_id_lag_1',
#  'item_price-shop_id-item_id_lag_1',
#  'target-item_category_id_lag_1',
#  'item_price-item_category_id_lag_1',
#  'target-shop_id-item_category_id_lag_1',
#  'item_price-shop_id-item_category_id_lag_1',
#  'target-shop_id_lag_2',
#  'item_price-shop_id_lag_2',
#  'target-item_id_lag_2',
#  'item_price-item_id_lag_2',
#  'target-shop_id-item_id_lag_2',
#  'item_price-shop_id-item_id_lag_2',
#  'target-item_category_id_lag_2',
#  'item_price-item_category_id_lag_2',
#  'target-shop_id-item_category_id_lag_2',
#  'item_price-shop_id-item_category_id_lag_2',
#  'target-shop_id_lag_3',
#  'item_price-shop_id_lag_3',
#  'target-item_id_lag_3',
#  'item_price-item_id_lag_3',
#  'target-shop_id-item_id_lag_3',
#  'item_price-shop_id-item_id_lag_3',
#  'target-item_category_id_lag_3',
#  'item_price-item_category_id_lag_3',
#  'target-shop_id-item_category_id_lag_3',
#  'item_price-shop_id-item_category_id_lag_3',
#  'target-shop_id_lag_6',
#  'item_price-shop_id_lag_6',
#  'target-item_id_lag_6',
#  'item_price-item_id_lag_6',
#  'target-shop_id-item_id_lag_6',
#  'item_price-shop_id-item_id_lag_6',
#  'target-item_category_id_lag_6',
#  'item_price-item_category_id_lag_6',
#  'target-shop_id-item_category_id_lag_6',
#  'item_price-shop_id-item_category_id_lag_6',
#  'target-shop_id_lag_12',
#  'item_price-shop_id_lag_12',
#  'target-item_id_lag_12',
#  'item_price-item_id_lag_12',
#  'target-shop_id-item_id_lag_12',
#  'item_price-shop_id-item_id_lag_12',
#  'target-item_category_id_lag_12',
#  'item_price-item_category_id_lag_12',
#  'target-shop_id-item_category_id_lag_12',
#  'item_price-shop_id-item_category_id_lag_12']

# %%
full_df
# Out:
#           shop_id  item_id  date_block_num        ID  item_cnt_month  dt_year  \
# 4836102         2       30              13       0.0             0.0     2014
# 4836103         2       31              13       0.0             0.0     2014
# 4836104         2       32              13       0.0             0.0     2014
# 4836105         2       33              13       0.0             0.0     2014
# 4836106         2       34              13       0.0             0.0     2014
# 4836107         2       36              13       0.0             0.0     2014
# 4836108         2       37              13       0.0             0.0     2014
# 4836109         2       40              13       0.0             0.0     2014
# 4836110         2       42              13       0.0             0.0     2014
# 4836111         2       44              13       0.0             0.0     2014
# 4836112         2       45              13       0.0             0.0     2014
# 4836113         2       46              13       0.0             0.0     2014
# 4836114         2       48              13       0.0             0.0     2014
# 4836115         2       49              13       0.0             0.0     2014
# 4836116         2       51              13       0.0             0.0     2014
# 4836117         2       52              13       0.0             0.0     2014
# 4836118         2       53              13       0.0             0.0     2014
# 4836119         2       55              13       0.0             0.0     2014
# 4836120         2       56              13       0.0             0.0     2014
# 4836121         2       57              13       0.0             0.0     2014
# 4836122         2       59              13       0.0             0.0     2014
# 4836123         2       65              13       0.0             0.0     2014
# 4836124         2       72              13       0.0             0.0     2014
# 4836125         2       75              13       0.0             0.0     2014
# 4836126         2       78              13       0.0             0.0     2014
# 4836127         2       81              13       0.0             0.0     2014
# 4836128         2       88              13       0.0             0.0     2014
# 4836129         2       93              13       0.0             0.0     2014
# 4836130         2       96              13       0.0             0.0     2014
# 4836131         2       99              13       0.0             0.0     2014
# ...           ...      ...             ...       ...             ...      ...
# 11128020       59    22022              34  149574.0             0.0     2015
# 11128021       59    22035              34  152638.0             0.0     2015
# 11128022       59    22050              34  149987.0             0.0     2015
# 11128023       59    22054              34  151671.0             0.0     2015
# 11128024       59    22059              34  150484.0             0.0     2015
# 11128025       59    22060              34  148504.0             0.0     2015
# 11128026       59    22068              34  152036.0             0.0     2015
# 11128027       59    22069              34  150483.0             0.0     2015
# 11128028       59    22071              34  149923.0             0.0     2015
# 11128029       59    22087              34  148487.0             0.0     2015
# 11128030       59    22088              34  148488.0             0.0     2015
# 11128031       59    22091              34  148489.0             0.0     2015
# 11128032       59    22092              34  149233.0             0.0     2015
# 11128033       59    22100              34  148490.0             0.0     2015
# 11128034       59    22101              34  148491.0             0.0     2015
# 11128035       59    22102              34  148492.0             0.0     2015
# 11128036       59    22104              34  149924.0             0.0     2015
# 11128037       59    22105              34  150485.0             0.0     2015
# 11128038       59    22106              34  150491.0             0.0     2015
# 11128039       59    22111              34  150490.0             0.0     2015
# 11128040       59    22118              34  148376.0             0.0     2015
# 11128041       59    22137              34  150489.0             0.0     2015
# 11128042       59    22139              34  150488.0             0.0     2015
# 11128043       59    22145              34  148798.0             0.0     2015
# 11128044       59    22154              34  150983.0             0.0     2015
# 11128045       59    22162              34  149575.0             0.0     2015
# 11128046       59    22163              34  148799.0             0.0     2015
# 11128047       59    22164              34  149242.0             0.0     2015
# 11128048       59    22166              34  152328.0             0.0     2015
# 11128049       59    22167              34  148377.0             0.0     2015
#
#           dt_month                                          item_name  \
# 4836102          2                         007: КООРДИНАТЫ «СКАЙФОЛЛ»
# 4836103          2                    007: КООРДИНАТЫ «СКАЙФОЛЛ» (BD)
# 4836104          2                                                1+1
# 4836105          2                                           1+1 (BD)
# 4836106          2                10 000 ЛЕТ ДО НАШЕЙ ЭРЫ WB (регион)
# 4836107          2                                 10 ЛЕТ СПУСТЯ (BD)
# 4836108          2                             10 ЛЕТ СПУСТЯ (регион)
# 4836109          2    100 Best classical melodies (mp3-CD) (Digipack)
# 4836110          2     100 Best romantic melodies (mp3-CD) (Digipack)
# 4836111          2  100 лучших мелодий против стресса (mp3-CD) (CD...
# 4836112          2   100 лучших народных песен (mp3-CD) (CD-Digipack)
# 4836113          2   100 лучших произведений Баха (mp3-CD) (Digipack)
# 4836114          2  100 лучших произведений Вивальди (mp3-CD) (CD-...
# 4836115          2  100 лучших произведений Моцарта (mp3-CD) (Digi...
# 4836116          2  100 лучших произведений классики (mp3-CD) (Dig...
# 4836117          2  100 лучших произведений фортепианной музыки (m...
# 4836118          2  100 лучших русских романсов (mp3-CD) (CD-Digip...
# 4836119          2      100 любимых маленьких сказок (mp3-CD) (Jewel)
# 4836120          2  100 любимых песен. Александра Пахмутова (подар...
# 4836121          2  100 пудов из мультхитов (подар. уп.) (mp3-CD) ...
# 4836122          2          100 шедевров классики (mp3-CD) (Digipack)
# 4836123          2  101 ДАЛМАТИНЕЦ 2:ПРИКЛЮЧЕНИЯ ПАТЧА В ЛОНДОНЕ (BD)
# 4836124          2                       11 ДРУЗЕЙ ОУШЕНА WB (регион)
# 4836125          2                       12 ДРУЗЕЙ ОУШЕНА WB (регион)
# 4836126          2                                         12 МЕСЯЦЕВ
# 4836127          2                          12 РОЖДЕСТВЕНСКИХ ЖЕЛАНИЙ
# 4836128          2                       13 ДРУЗЕЙ ОУШЕНА WB (регион)
# 4836129          2  15 знаменитых сказок  Детям от 0 до 3 лет (mp3...
# 4836130          2                  1812. ЭНЦИКЛОПЕДИЯ ВОЙНЫ (регион)
# 4836131          2                        1812: УЛАНСКАЯ БАЛЛАДА (BD)
# ...            ...                                                ...
# 11128020        11                                       ЭКИПАЖ (rem)
# 11128021        11                                ЭЛВИН И БУРУНДУКИ 2
# 11128022        11                                       ЭМПАЙР СТЭЙТ
# 11128023        11                      ЭПИДЕМИЯ  Сокровище Энии  2LP
# 11128024        11                                    ЭПИК (3D BD+BD)
# 11128025        11                                          ЭПИК (BD)
# 11128026        11                           ЭТА-ДУРАЦКАЯ-ЛЮБОВЬ (BD)
# 11128027        11                       ЭТА-ДУРАЦКАЯ-ЛЮБОВЬ (регион)
# 11128028        11                               ЭТОТ НЕЛОВКИЙ МОМЕНТ
# 11128029        11                  Элемент питания DURACELL LR03-BC2
# 11128030        11                  Элемент питания DURACELL LR06-BC2
# 11128031        11          Элемент питания DURACELL TURBO LR 03 2*BL
# 11128032        11            Элемент питания DURACELL TURBO LR6 2*BL
# 11128033        11                        Энциклопедия Adventure Time
# 11128034        11           Энциклопедия Dragon Age Мир Тедаса Том 1
# 11128035        11                          Энциклопедия Мир Ведьмака
# 11128036        11                           Ю-ПИТЕР  Гудгора (фирм.)
# 11128037        11  ЮГО-ЗАПАДНАЯ АМЕРИКА: ОТ ДОЛИНЫ СМЕРТИ ДО ВЕЛИ...
# 11128038        11  ЮЖНЫЕ МОРЯ: АТОЛЛ БИКИНИ И МАРШАЛЛОВЫ ОСТРОВА ...
# 11128039        11  Юмор и сатира  1  Рассказы русских писателей  ...
# 11128040        11                   Я ЛЮБЛЮ ТЕБЯ, ФИЛЛИП МОРРИС (BD)
# 11128041        11                                           Я, РОБОТ
# 11128042        11                                   Я, РОБОТ (3D BD)
# 11128043        11                               Я, ФРАНКЕНШТЕЙН (BD)
# 11128044        11                                  ЯВЛЕНИЕ 2012 (BD)
# 11128045        11                                             ЯРОСТЬ
# 11128046        11                                   ЯРОСТЬ ( регион)
# 11128047        11                                        ЯРОСТЬ (BD)
# 11128048        11    Язык запросов 1С:Предприятия  [Цифровая версия]
# 11128049        11  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...
#
#           item_category_id  item_name_tfidf_dcp_0  \
# 4836102                 40               0.001040
# 4836103                 37               0.243195
# 4836104                 40              -0.000000
# 4836105                 37               0.976919
# 4836106                 40               0.016747
# 4836107                 37               0.251092
# 4836108                 40               0.009630
# 4836109                 57               0.005770
# 4836110                 57               0.006035
# 4836111                 57               0.008027
# 4836112                 57               0.007133
# 4836113                 57               0.006236
# 4836114                 57               0.006926
# 4836115                 57               0.006236
# 4836116                 57               0.005480
# 4836117                 57               0.007265
# 4836118                 57               0.007052
# 4836119                 43               0.009299
# 4836120                 57               0.007794
# 4836121                 57               0.013700
# 4836122                 57               0.005660
# 4836123                 37               0.231547
# 4836124                 40               0.020668
# 4836125                 40               0.021195
# 4836126                 40               0.003110
# 4836127                 40               0.002292
# 4836128                 40               0.021151
# 4836129                 43               0.010716
# 4836130                 40               0.007826
# 4836131                 37               0.201598
# 11128035                                     0.0
# 11128036                                     0.0
# 11128037                                    11.0
# 11128038                                    11.0
# 11128039                                     0.0
# 11128040                                     0.0
# 11128041                                     0.0
# 11128042                                    11.0
# 11128043                                     0.0
# 11128044                                     0.0
# 11128045                                     0.0
# 11128046                                     0.0
# 11128047                                     0.0
# 11128048                                     0.0
# 11128049                                     3.0
#
#           item_price-shop_id-item_category_id_lag_12
# 4836102                                   260.250000
# 4836103                                   577.333333
# 4836104                                   260.250000
# 4836105                                   577.333333
# 4836106                                   260.250000
# 4836107                                   577.333333
# 4836108                                     0.000000
# 4836109                                     0.000000
# 4836110                                     0.000000
# 4836111                                     0.000000
# 4836112                                     0.000000
# 4836113                                     0.000000
# 4836114                                     0.000000
# 4836115                                     0.000000
# 4836116                                     0.000000
# 4836117                                     0.000000
# 4836118                                     0.000000
# 4836119                                     0.000000
# 4836120                                     0.000000
# 4836121                                     0.000000
# 4836122                                     0.000000
# 4836123                                     0.000000
# 4836124                                   260.250000
# 4836125                                   260.250000
# 4836126                                     0.000000
# 4836127                                     0.000000
# 4836128                                   260.250000
# 4836129                                     0.000000
# 4836130                                   260.250000
# 4836131                                     0.000000
# ...                                              ...
# 11128020                                    0.000000
# 11128021                                    0.000000
# 11128022                                  275.435028
# 11128023                                    0.000000
# 11128024                                  898.090909
# 11128025                                  529.428571
# 11128026                                    0.000000
# 11128027                                    0.000000
# 11128028                                  275.435028
# 11128029                                   88.285714
# 11128030                                   88.285714
# 11128031                                   88.285714
# 11128032                                   88.285714
# 11128033                                    0.000000
# 11128034                                    0.000000
# 11128035                                    0.000000
# 11128036                                    0.000000
# 11128037                                  898.090909
# 11128038                                  898.090909
# 11128039                                    0.000000
# 11128040                                    0.000000
# 11128041                                    0.000000
# 11128042                                  898.090909
# 11128043                                    0.000000
# 11128044                                    0.000000
# 11128045                                    0.000000
# 11128046                                    0.000000
# 11128047                                    0.000000
# 11128048                                    0.000000
# 11128049                                  282.333333
#
# [6291948 rows x 78 columns]

# %% [markdown]
# **clip target**

# %%
full_df['item_cnt_month'] = full_df['item_cnt_month'].clip(0, 20)

# %% [markdown]
# ## Test features use lightgbm

# %%
dates = full_df['date_block_num'].copy()
XX_trn = full_df[dates <= 32][feature_columns]
yy_trn = full_df[dates <= 32][label_col]
XX_val = full_df[dates == 33][feature_columns]
yy_val = full_df[dates == 33][label_col]

# %%
trn_lgb = lgb.Dataset(XX_trn, yy_trn)
val_lgb = lgb.Dataset(XX_val, yy_val)

lgb_params = {
    'application': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.1,
    'max_depth': 5,
    'num_leaves': 20,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.5,
    'bagging_freq': 1,
    'seed': 0,
}
train_round = 150

bst = lgb.train(lgb_params, trn_lgb, train_round, valid_sets=[trn_lgb, val_lgb], early_stopping_rounds=20)
# Out:
# [1]	training's rmse: 1.13974	valid_1's rmse: 1.10691
# Training until validation scores don't improve for 20 rounds.
# [2]	training's rmse: 1.09969	valid_1's rmse: 1.08105
# [3]	training's rmse: 1.06622	valid_1's rmse: 1.052
# [4]	training's rmse: 1.03792	valid_1's rmse: 1.02607
# [5]	training's rmse: 1.00609	valid_1's rmse: 1.0081
# [6]	training's rmse: 0.983047	valid_1's rmse: 0.996264
# [7]	training's rmse: 0.958717	valid_1's rmse: 0.984539
# [8]	training's rmse: 0.940494	valid_1's rmse: 0.978195
# [9]	training's rmse: 0.923412	valid_1's rmse: 0.97096
# [10]	training's rmse: 0.908627	valid_1's rmse: 0.96556
# [11]	training's rmse: 0.895897	valid_1's rmse: 0.960899
# [12]	training's rmse: 0.885635	valid_1's rmse: 0.957885
# [13]	training's rmse: 0.877481	valid_1's rmse: 0.956268
# [14]	training's rmse: 0.870309	valid_1's rmse: 0.953756
# [15]	training's rmse: 0.863621	valid_1's rmse: 0.948511
# [16]	training's rmse: 0.857585	valid_1's rmse: 0.943964
# [17]	training's rmse: 0.85216	valid_1's rmse: 0.940886
# [18]	training's rmse: 0.847363	valid_1's rmse: 0.940759
# [19]	training's rmse: 0.843153	valid_1's rmse: 0.93655
# [20]	training's rmse: 0.839348	valid_1's rmse: 0.936089
# [21]	training's rmse: 0.83628	valid_1's rmse: 0.933524
# [22]	training's rmse: 0.833389	valid_1's rmse: 0.932182
# [23]	training's rmse: 0.830867	valid_1's rmse: 0.93102
# [24]	training's rmse: 0.828629	valid_1's rmse: 0.930598
# [25]	training's rmse: 0.826597	valid_1's rmse: 0.930365
# [26]	training's rmse: 0.824856	valid_1's rmse: 0.929056
# [27]	training's rmse: 0.822906	valid_1's rmse: 0.927651
# [28]	training's rmse: 0.821675	valid_1's rmse: 0.927392
# [29]	training's rmse: 0.819993	valid_1's rmse: 0.923135
# [30]	training's rmse: 0.818553	valid_1's rmse: 0.922565
# [31]	training's rmse: 0.817087	valid_1's rmse: 0.920944
# [32]	training's rmse: 0.816248	valid_1's rmse: 0.920748
# [33]	training's rmse: 0.815	valid_1's rmse: 0.919851
# [34]	training's rmse: 0.814035	valid_1's rmse: 0.919468
# [35]	training's rmse: 0.813102	valid_1's rmse: 0.918926
# [36]	training's rmse: 0.811964	valid_1's rmse: 0.917632
# [37]	training's rmse: 0.810477	valid_1's rmse: 0.917729
# [38]	training's rmse: 0.80956	valid_1's rmse: 0.916747
# [39]	training's rmse: 0.807378	valid_1's rmse: 0.915751
# [40]	training's rmse: 0.806419	valid_1's rmse: 0.915732
# [41]	training's rmse: 0.804881	valid_1's rmse: 0.914615
# [42]	training's rmse: 0.803263	valid_1's rmse: 0.914257
# [43]	training's rmse: 0.802426	valid_1's rmse: 0.91363
# [44]	training's rmse: 0.80188	valid_1's rmse: 0.913607
# [45]	training's rmse: 0.80035	valid_1's rmse: 0.912495
# [46]	training's rmse: 0.799287	valid_1's rmse: 0.91185
# [47]	training's rmse: 0.798678	valid_1's rmse: 0.911151
# [48]	training's rmse: 0.797932	valid_1's rmse: 0.910986
# [49]	training's rmse: 0.797465	valid_1's rmse: 0.910579
# [50]	training's rmse: 0.796443	valid_1's rmse: 0.907395
# [51]	training's rmse: 0.795858	valid_1's rmse: 0.907016
# [52]	training's rmse: 0.79505	valid_1's rmse: 0.905703
# [53]	training's rmse: 0.794827	valid_1's rmse: 0.905708
# [54]	training's rmse: 0.794441	valid_1's rmse: 0.905317
# [55]	training's rmse: 0.793662	valid_1's rmse: 0.906127
# [56]	training's rmse: 0.793094	valid_1's rmse: 0.906146
# [57]	training's rmse: 0.792672	valid_1's rmse: 0.905985
# [58]	training's rmse: 0.791797	valid_1's rmse: 0.906157
# [59]	training's rmse: 0.790843	valid_1's rmse: 0.905488
# [60]	training's rmse: 0.790396	valid_1's rmse: 0.904852
# [61]	training's rmse: 0.790018	valid_1's rmse: 0.904649
# [62]	training's rmse: 0.789756	valid_1's rmse: 0.904419
# [63]	training's rmse: 0.789449	valid_1's rmse: 0.90388
# [64]	training's rmse: 0.788169	valid_1's rmse: 0.903336
# [65]	training's rmse: 0.787911	valid_1's rmse: 0.903013
# [66]	training's rmse: 0.787622	valid_1's rmse: 0.902812
# [67]	training's rmse: 0.786879	valid_1's rmse: 0.901788
# [68]	training's rmse: 0.786493	valid_1's rmse: 0.901896
# [69]	training's rmse: 0.786123	valid_1's rmse: 0.901797
# [70]	training's rmse: 0.785734	valid_1's rmse: 0.901577
# [71]	training's rmse: 0.785439	valid_1's rmse: 0.901936
# [72]	training's rmse: 0.784973	valid_1's rmse: 0.901151
# [73]	training's rmse: 0.78369	valid_1's rmse: 0.897727
# [74]	training's rmse: 0.783303	valid_1's rmse: 0.896925
# [75]	training's rmse: 0.782401	valid_1's rmse: 0.895978
# [76]	training's rmse: 0.781971	valid_1's rmse: 0.89584
# [77]	training's rmse: 0.781535	valid_1's rmse: 0.896119
# [78]	training's rmse: 0.781268	valid_1's rmse: 0.896068
# [79]	training's rmse: 0.781084	valid_1's rmse: 0.896044
# [80]	training's rmse: 0.780695	valid_1's rmse: 0.896259
# [81]	training's rmse: 0.780496	valid_1's rmse: 0.896304
# [82]	training's rmse: 0.78017	valid_1's rmse: 0.895995
# [83]	training's rmse: 0.779838	valid_1's rmse: 0.895767
# [84]	training's rmse: 0.779459	valid_1's rmse: 0.895701
# [85]	training's rmse: 0.779284	valid_1's rmse: 0.895647
# [86]	training's rmse: 0.778928	valid_1's rmse: 0.895101
# [87]	training's rmse: 0.778589	valid_1's rmse: 0.895004
# [88]	training's rmse: 0.778115	valid_1's rmse: 0.895047
# [89]	training's rmse: 0.7775	valid_1's rmse: 0.894917
# [90]	training's rmse: 0.776834	valid_1's rmse: 0.89335
# [91]	training's rmse: 0.776403	valid_1's rmse: 0.892449
# [92]	training's rmse: 0.776031	valid_1's rmse: 0.89199
# [93]	training's rmse: 0.775621	valid_1's rmse: 0.89175
# [94]	training's rmse: 0.77547	valid_1's rmse: 0.891634
# [95]	training's rmse: 0.775129	valid_1's rmse: 0.89153
# [96]	training's rmse: 0.774761	valid_1's rmse: 0.891555
# [97]	training's rmse: 0.774423	valid_1's rmse: 0.891883
# [98]	training's rmse: 0.774246	valid_1's rmse: 0.891747
# [99]	training's rmse: 0.774096	valid_1's rmse: 0.891653
# [100]	training's rmse: 0.773835	valid_1's rmse: 0.891479
# Did not meet early stopping. Best iteration is:
# [100]	training's rmse: 0.773835	valid_1's rmse: 0.891479

# %%
imp_df = pd.DataFrame([bst.feature_importance()], columns=feature_columns, index=['importance']).T.sort_values(by='importance', ascending=False)
imp_df
# Out:
#                                             importance
# target-item_id_lag_1                               192
# mean_encoding-shop_id-item_id                      161
# mean_encoding-item_id                              154
# target-shop_id-item_id_lag_1                       109
# dt_month                                            93
# target-item_id_lag_2                                72
# mean_encoding-shop_id                               61
# item_name_tfidf_dcp_4                               56
# target-item_category_id_lag_2                       51
# target-item_category_id_lag_1                       49
# item_price-shop_id-item_id_lag_1                    47
# target-shop_id-item_category_id_lag_1               47
# target-shop_id-item_id_lag_2                        45
# target-item_id_lag_3                                43
# target-shop_id_lag_2                                40
# item_price-item_id_lag_1                            36
# item_category_id                                    34
# item_name_tfidf_dcp_1                               34
# item_price-item_category_id_lag_1                   30
# target-shop_id_lag_1                                28
# item_price-item_id_lag_2                            27
# target-shop_id-item_id_lag_3                        27
# dt_year                                             25
# item_name_tfidf_dcp_3                               24
# item_price-item_category_id_lag_3                   21
# target-item_category_id_lag_3                       21
# target-shop_id_lag_12                               20
# item_price-item_category_id_lag_2                   20
# target-shop_id_lag_3                                19
# target-item_id_lag_12                               19
# ...                                                ...
# target-shop_id-item_category_id_lag_2               16
# target-shop_id_lag_6                                16
# item_price-item_id_lag_6                            16
# item_name_tfidf_dcp_0                               14
# item_price-shop_id_lag_2                            14
# item_price-shop_id-item_id_lag_2                    13
# item_price-shop_id_lag_1                            13
# item_name_words_count                               12
# item_price-item_id_lag_3                            12
# item_price-shop_id_lag_3                            11
# item_price-shop_id-item_id_lag_3                    10
# target-item_category_id_lag_12                      10
# item_name_tfidf_dcp_2                               10
# target-shop_id-item_id_lag_6                         9
# item_price-item_category_id_lag_6                    9
# item_price-shop_id_lag_12                            9
# item_price-shop_id_lag_6                             8
# item_price-shop_id-item_category_id_lag_1            8
# item_price-item_id_lag_12                            7
# item_price-item_category_id_lag_12                   6
# item_price-shop_id-item_category_id_lag_2            6
# item_price-shop_id-item_id_lag_6                     5
# item_price-shop_id-item_category_id_lag_6            4
# item_price-shop_id-item_id_lag_12                    3
# target-shop_id-item_category_id_lag_3                3
# target-shop_id-item_category_id_lag_6                2
# target-shop_id-item_id_lag_12                        2
# item_price-shop_id-item_category_id_lag_3            2
# target-shop_id-item_category_id_lag_12               1
# item_price-shop_id-item_category_id_lag_12           1
#
# [62 rows x 1 columns]

# %% [markdown]
# ## Save

# %%
# %%time
features_save(full_df, feature_columns)
# Out:
# CPU times: user 10min 6s, sys: 26 s, total: 10min 32s
# Wall time: 10min 41s
