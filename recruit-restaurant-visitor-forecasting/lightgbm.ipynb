# %%
# coding: utf-8
import os
import datetime

import pandas as pd
import numpy as np
import scipy
import lightgbm as lgb
import xgboost as xgb
from sklearn import metrics
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt
import seaborn as sns

from mydatools.features_analyze import get_top_k_corr
from mydatools.plot import plot_grid_search_result

from common import read_features, save_features

% matplotlib inline

# %% [markdown]
# ## Config

# %%
# trn_path = './data/input/train.csv'
# tst_path = './data/input/test.csv'
id_col = 'id'
label_col = 'visitors'

submission_path = './data/output/submission/lightgbm.csv'
output_id_col = id_col
output_label_col = label_col

# %% [markdown]
# ## Load Data

# %%
full_df, feature_columns = read_features()

# %%
# dataset type
is_trn = full_df['ds_type'] == 'trn'
is_tst = full_df['ds_type'] == 'tst'

# %%
full_df.head()
# Out:
#            air_store_id ds_type                               id  visit_date  \
# 0  air_ba937bf13d40fb24     trn  air_ba937bf13d40fb24_2016-01-13  2016-01-13
# 1  air_ba937bf13d40fb24     trn  air_ba937bf13d40fb24_2016-01-14  2016-01-14
# 2  air_ba937bf13d40fb24     trn  air_ba937bf13d40fb24_2016-01-15  2016-01-15
# 3  air_ba937bf13d40fb24     trn  air_ba937bf13d40fb24_2016-01-16  2016-01-16
# 4  air_ba937bf13d40fb24     trn  air_ba937bf13d40fb24_2016-01-18  2016-01-18
#
#    visitors  visitors_o air_genre_name                 air_area_name  \
# 0  3.258097          25     Dining bar  Tōkyō-to Minato-ku Shibakōen
# 1  3.496508          32     Dining bar  Tōkyō-to Minato-ku Shibakōen
# 2  3.401197          29     Dining bar  Tōkyō-to Minato-ku Shibakōen
# 3  3.135494          22     Dining bar  Tōkyō-to Minato-ku Shibakōen
# 4  1.945910           6     Dining bar  Tōkyō-to Minato-ku Shibakōen
#
#     latitude   longitude                     ...                      \
# 0  35.658068  139.751599                     ...
# 1  35.658068  139.751599                     ...
# 2  35.658068  139.751599                     ...
# 3  35.658068  139.751599                     ...
# 4  35.658068  139.751599                     ...
#
#    air_genre_name-visit_dayofweek-visitors_min  \
# 0                                     0.693147
# 1                                     0.693147
# 2                                     0.693147
# 3                                     0.693147
# 4                                     0.693147
#
#    air_genre_name-visit_dayofweek-visitors_q25  \
# 0                                     1.945910
# 1                                     2.079442
# 2                                     2.302585
# 3                                     2.484907
# 4                                     1.791759
#
#    air_genre_name-visit_dayofweek-visitors_q50  \
# 0                                     2.639057
# 1                                     2.639057
# 2                                     2.944439
# 3                                     3.091042
# 4                                     2.484907
#
#    air_genre_name-visit_dayofweek-visitors_q75  \
# 0                                     3.218876
# 1                                     3.218876
# 2                                     3.465736
# 3                                     3.583519
# 4                                     3.044522
#
#    air_area_name-visit_dayofweek-visitors_avg  \
# 0                                    2.777286
# 1                                    2.754310
# 2                                    2.925904
# 3                                    2.730508
# 4                                    2.450613
#
#    air_area_name-visit_dayofweek-visitors_max  \
# 0                                    4.976734
# 1                                    4.700480
# 2                                    4.812184
# 3                                    4.867534
# 4                                    5.723585
#
#    air_area_name-visit_dayofweek-visitors_min  \
# 0                                    0.693147
# 1                                    0.693147
# 2                                    0.693147
# 3                                    0.693147
# 4                                    0.693147
#
#    air_area_name-visit_dayofweek-visitors_q25  \
# 0                                    2.197225
# 1                                    2.197225
# 2                                    2.397895
# 3                                    2.079442
# 4                                    1.791759
#
#    air_area_name-visit_dayofweek-visitors_q50  \
# 0                                    2.890372
# 1                                    2.833213
# 2                                    3.044522
# 3                                    2.772589
# 4                                    2.484907
#
#    air_area_name-visit_dayofweek-visitors_q75
# 0                                    3.401197
# 1                                    3.367296
# 2                                    3.555348
# 3                                    3.367296
# 4                                    3.091042
#
# [5 rows x 95 columns]

# %%
feature_columns
# Out:
# ['air_genre_name_Asian',
#  'air_genre_name_Bar/Cocktail',
#  'air_genre_name_Cafe/Sweets',
#  'air_genre_name_Creative cuisine',
#  'air_genre_name_Dining bar',
#  'air_genre_name_International cuisine',
#  'air_genre_name_Italian/French',
#  'air_genre_name_Izakaya',
#  'air_genre_name_Japanese food',
#  'air_genre_name_Karaoke/Party',
#  'air_genre_name_Okonomiyaki/Monja/Teppanyaki',
#  'air_genre_name_Other',
#  'air_genre_name_Western food',
#  'air_genre_name_Yakiniku/Korean food',
#  'latitude',
#  'longitude',
#  'holiday_flg',
#  'visit_month',
#  'visit_dayofweek',
#  'visit_days_in_month',
#  'reserve_count',
#  'total_reserve_visitors',
#  'ahead_reserve_hours_median',
#  'reserve_in_1day_count',
#  'reserve_in_2day_count',
#  'reserve_in_3day_count',
#  'reserve_in_7day_count',
#  'reserve_in_30day_count',
#  'reserve_in_1day_visitors',
#  'reserve_in_2day_visitors',
#  'reserve_in_3day_visitors',
#  'reserve_in_7day_visitors',
#  'reserve_in_30day_visitors',
#  'air_store_id-visitors_avg',
#  'air_store_id-visitors_max',
#  'air_store_id-visitors_min',
#  'air_store_id-visitors_q25',
#  'air_store_id-visitors_q50',
#  'air_store_id-visitors_q75',
#  'visit_dayofweek-visitors_avg',
#  'visit_dayofweek-visitors_max',
#  'visit_dayofweek-visitors_min',
#  'visit_dayofweek-visitors_q25',
#  'visit_dayofweek-visitors_q50',
#  'visit_dayofweek-visitors_q75',
#  'air_store_id-visit_dayofweek-visitors_avg',
#  'air_store_id-visit_dayofweek-visitors_max',
#  'air_store_id-visit_dayofweek-visitors_min',
#  'air_store_id-visit_dayofweek-visitors_q25',
#  'air_store_id-visit_dayofweek-visitors_q50',
#  'air_store_id-visit_dayofweek-visitors_q75',
#  'visit_month-visitors_avg',
#  'visit_month-visitors_max',
#  'visit_month-visitors_min',
#  'visit_month-visitors_q25',
#  'visit_month-visitors_q50',
#  'visit_month-visitors_q75',
#  'air_genre_name-visitors_avg',
#  'air_genre_name-visitors_max',
#  'air_genre_name-visitors_min',
#  'air_genre_name-visitors_q25',
#  'air_genre_name-visitors_q50',
#  'air_genre_name-visitors_q75',
#  'air_area_name-visitors_avg',
#  'air_area_name-visitors_max',
#  'air_area_name-visitors_min',
#  'air_area_name-visitors_q25',
#  'air_area_name-visitors_q50',
#  'air_area_name-visitors_q75',
#  'air_genre_name-air_area_name-visitors_avg',
#  'air_genre_name-air_area_name-visitors_max',
#  'air_genre_name-air_area_name-visitors_min',
#  'air_genre_name-air_area_name-visitors_q25',
#  'air_genre_name-air_area_name-visitors_q50',
#  'air_genre_name-air_area_name-visitors_q75',
#  'air_genre_name-visit_dayofweek-visitors_avg',
#  'air_genre_name-visit_dayofweek-visitors_max',
#  'air_genre_name-visit_dayofweek-visitors_min',
#  'air_genre_name-visit_dayofweek-visitors_q25',
#  'air_genre_name-visit_dayofweek-visitors_q50',
#  'air_genre_name-visit_dayofweek-visitors_q75',
#  'air_area_name-visit_dayofweek-visitors_avg',
#  'air_area_name-visit_dayofweek-visitors_max',
#  'air_area_name-visit_dayofweek-visitors_min',
#  'air_area_name-visit_dayofweek-visitors_q25',
#  'air_area_name-visit_dayofweek-visitors_q50',
#  'air_area_name-visit_dayofweek-visitors_q75']

# %% [markdown]
# ## Preprocessing

# %%
trn_df = full_df[is_trn]
tst_df = full_df[is_tst]

X = trn_df[feature_columns]
y = trn_df[label_col]
X_trn, X_val, y_trn, y_val = train_test_split(X, y, test_size=0.2, random_state=0)

X_tst = tst_df[feature_columns]

# %% [markdown]
# ## LightGBM

# %%
trn_lgb = lgb.Dataset(X_trn.values, y_trn)
val_lgb = lgb.Dataset(X_val.values, y_val, reference=trn_lgb)

# %%
params = {
    'boosting': 'gbdt',
    'application': 'mse',
    'metric': 'rmse',
    'learning_rate': 0.05,
    'max_depth': 5,
    'num_leaves': 20,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.5,
    'bagging_freq': 1,
    'seed': 0,
    'reg_alpha': 0.1,
}
lgbm = lgb.train(params, trn_lgb, 1000, valid_sets=[trn_lgb, val_lgb], early_stopping_rounds=20)
# Out:
# [1]	training's rmse: 0.784733	valid_1's rmse: 0.781374
# Training until validation scores don't improve for 20 rounds.
# [2]	training's rmse: 0.762613	valid_1's rmse: 0.759405
# [3]	training's rmse: 0.742228	valid_1's rmse: 0.739179
# [4]	training's rmse: 0.723149	valid_1's rmse: 0.720248
# [5]	training's rmse: 0.705663	valid_1's rmse: 0.702906
# [6]	training's rmse: 0.68954	valid_1's rmse: 0.686949
# [7]	training's rmse: 0.67455	valid_1's rmse: 0.672097
# [8]	training's rmse: 0.660546	valid_1's rmse: 0.658234
# [9]	training's rmse: 0.647575	valid_1's rmse: 0.645376
# [10]	training's rmse: 0.635706	valid_1's rmse: 0.633616
# [11]	training's rmse: 0.62488	valid_1's rmse: 0.622913
# [12]	training's rmse: 0.614941	valid_1's rmse: 0.613087
# [13]	training's rmse: 0.60567	valid_1's rmse: 0.603924
# [14]	training's rmse: 0.597205	valid_1's rmse: 0.595563
# [15]	training's rmse: 0.58948	valid_1's rmse: 0.587946
# [16]	training's rmse: 0.582307	valid_1's rmse: 0.580877
# [17]	training's rmse: 0.575864	valid_1's rmse: 0.574522
# [18]	training's rmse: 0.569823	valid_1's rmse: 0.568587
# [19]	training's rmse: 0.564334	valid_1's rmse: 0.563176
# [20]	training's rmse: 0.559324	valid_1's rmse: 0.558245
# [21]	training's rmse: 0.554793	valid_1's rmse: 0.553798
# [22]	training's rmse: 0.550688	valid_1's rmse: 0.549768
# [23]	training's rmse: 0.54678	valid_1's rmse: 0.545933
# [24]	training's rmse: 0.543283	valid_1's rmse: 0.542493
# [25]	training's rmse: 0.540086	valid_1's rmse: 0.539359
# [26]	training's rmse: 0.537154	valid_1's rmse: 0.536481
# [27]	training's rmse: 0.534446	valid_1's rmse: 0.533839
# [28]	training's rmse: 0.531983	valid_1's rmse: 0.531423
# [29]	training's rmse: 0.529769	valid_1's rmse: 0.529254
# [30]	training's rmse: 0.527733	valid_1's rmse: 0.527272
# [31]	training's rmse: 0.525883	valid_1's rmse: 0.525476
# [32]	training's rmse: 0.524154	valid_1's rmse: 0.52379
# [33]	training's rmse: 0.522582	valid_1's rmse: 0.522279
# [34]	training's rmse: 0.52117	valid_1's rmse: 0.520892
# [35]	training's rmse: 0.519881	valid_1's rmse: 0.519653
# [36]	training's rmse: 0.518691	valid_1's rmse: 0.518533
# [37]	training's rmse: 0.517613	valid_1's rmse: 0.51747
# [38]	training's rmse: 0.516604	valid_1's rmse: 0.516489
# [39]	training's rmse: 0.515667	valid_1's rmse: 0.51557
# [40]	training's rmse: 0.514843	valid_1's rmse: 0.514771
# [41]	training's rmse: 0.514062	valid_1's rmse: 0.514052
# [42]	training's rmse: 0.513342	valid_1's rmse: 0.513339
# [43]	training's rmse: 0.512693	valid_1's rmse: 0.512717
# [44]	training's rmse: 0.512064	valid_1's rmse: 0.512136
# [45]	training's rmse: 0.511484	valid_1's rmse: 0.511599
# [46]	training's rmse: 0.510992	valid_1's rmse: 0.511125
# [47]	training's rmse: 0.510507	valid_1's rmse: 0.510668
# [48]	training's rmse: 0.510051	valid_1's rmse: 0.510239
# [49]	training's rmse: 0.50965	valid_1's rmse: 0.509863
# [50]	training's rmse: 0.509236	valid_1's rmse: 0.509472
# [51]	training's rmse: 0.508876	valid_1's rmse: 0.509151
# [52]	training's rmse: 0.508552	valid_1's rmse: 0.508845
# [53]	training's rmse: 0.508257	valid_1's rmse: 0.508549
# [54]	training's rmse: 0.507971	valid_1's rmse: 0.508299
# [55]	training's rmse: 0.507704	valid_1's rmse: 0.50805
# [56]	training's rmse: 0.507476	valid_1's rmse: 0.507832
# [57]	training's rmse: 0.507266	valid_1's rmse: 0.507664
# [58]	training's rmse: 0.507035	valid_1's rmse: 0.507453
# [59]	training's rmse: 0.506841	valid_1's rmse: 0.507261
# [60]	training's rmse: 0.506672	valid_1's rmse: 0.507093
# [61]	training's rmse: 0.506509	valid_1's rmse: 0.50695
# [62]	training's rmse: 0.506328	valid_1's rmse: 0.506782
# [63]	training's rmse: 0.506163	valid_1's rmse: 0.506645
# [64]	training's rmse: 0.505974	valid_1's rmse: 0.506493
# [65]	training's rmse: 0.505773	valid_1's rmse: 0.506325
# [66]	training's rmse: 0.505649	valid_1's rmse: 0.506209
# [67]	training's rmse: 0.505517	valid_1's rmse: 0.506093
# [68]	training's rmse: 0.505388	valid_1's rmse: 0.505985
# [69]	training's rmse: 0.505251	valid_1's rmse: 0.505852
# [70]	training's rmse: 0.505124	valid_1's rmse: 0.505759
# [71]	training's rmse: 0.504975	valid_1's rmse: 0.505622
# [72]	training's rmse: 0.504875	valid_1's rmse: 0.505545
# [73]	training's rmse: 0.504771	valid_1's rmse: 0.50546
# [74]	training's rmse: 0.504673	valid_1's rmse: 0.505387
# [75]	training's rmse: 0.504578	valid_1's rmse: 0.505297
# [76]	training's rmse: 0.504474	valid_1's rmse: 0.505237
# [77]	training's rmse: 0.50439	valid_1's rmse: 0.505161
# [78]	training's rmse: 0.504311	valid_1's rmse: 0.505106
# [79]	training's rmse: 0.504179	valid_1's rmse: 0.504997
# [80]	training's rmse: 0.504081	valid_1's rmse: 0.504906
# [81]	training's rmse: 0.503973	valid_1's rmse: 0.504816
# [82]	training's rmse: 0.503911	valid_1's rmse: 0.504767
# [83]	training's rmse: 0.503845	valid_1's rmse: 0.50471
# [84]	training's rmse: 0.503711	valid_1's rmse: 0.504586
# [85]	training's rmse: 0.503643	valid_1's rmse: 0.504532
# [86]	training's rmse: 0.503582	valid_1's rmse: 0.504492
# [87]	training's rmse: 0.503489	valid_1's rmse: 0.504423
# [88]	training's rmse: 0.503402	valid_1's rmse: 0.504352
# [89]	training's rmse: 0.503341	valid_1's rmse: 0.504315
# [90]	training's rmse: 0.503299	valid_1's rmse: 0.504291
# [91]	training's rmse: 0.503191	valid_1's rmse: 0.504192
# [92]	training's rmse: 0.503104	valid_1's rmse: 0.504114
# [93]	training's rmse: 0.503049	valid_1's rmse: 0.504085
# [94]	training's rmse: 0.502989	valid_1's rmse: 0.504036
# [95]	training's rmse: 0.502923	valid_1's rmse: 0.503973
# [96]	training's rmse: 0.502856	valid_1's rmse: 0.503926
# [97]	training's rmse: 0.502797	valid_1's rmse: 0.503874
# [98]	training's rmse: 0.50275	valid_1's rmse: 0.503838
# [99]	training's rmse: 0.502669	valid_1's rmse: 0.503777
# [100]	training's rmse: 0.502614	valid_1's rmse: 0.503748
# [101]	training's rmse: 0.502532	valid_1's rmse: 0.503696
# [102]	training's rmse: 0.502482	valid_1's rmse: 0.503659
# [103]	training's rmse: 0.502434	valid_1's rmse: 0.503636
# [104]	training's rmse: 0.502386	valid_1's rmse: 0.503612
# [105]	training's rmse: 0.502301	valid_1's rmse: 0.503551
# [106]	training's rmse: 0.502254	valid_1's rmse: 0.503517
# [107]	training's rmse: 0.502188	valid_1's rmse: 0.503473
# [108]	training's rmse: 0.502153	valid_1's rmse: 0.503445
# [109]	training's rmse: 0.502081	valid_1's rmse: 0.503389
# [110]	training's rmse: 0.502019	valid_1's rmse: 0.503356
# [111]	training's rmse: 0.501917	valid_1's rmse: 0.503259
# [112]	training's rmse: 0.501877	valid_1's rmse: 0.503221
# [113]	training's rmse: 0.501825	valid_1's rmse: 0.503172
# [114]	training's rmse: 0.501765	valid_1's rmse: 0.503135
# [115]	training's rmse: 0.501719	valid_1's rmse: 0.503127
# [116]	training's rmse: 0.501648	valid_1's rmse: 0.503093
# [117]	training's rmse: 0.50161	valid_1's rmse: 0.503073
# [118]	training's rmse: 0.501579	valid_1's rmse: 0.503042
# [119]	training's rmse: 0.501444	valid_1's rmse: 0.502916
# [120]	training's rmse: 0.501366	valid_1's rmse: 0.502869
# [121]	training's rmse: 0.501325	valid_1's rmse: 0.50285
# [122]	training's rmse: 0.501267	valid_1's rmse: 0.50279
# [123]	training's rmse: 0.501194	valid_1's rmse: 0.502732
# [124]	training's rmse: 0.501158	valid_1's rmse: 0.502726
# [125]	training's rmse: 0.501115	valid_1's rmse: 0.5027
# [126]	training's rmse: 0.501062	valid_1's rmse: 0.502644
# [127]	training's rmse: 0.501018	valid_1's rmse: 0.502599
# [128]	training's rmse: 0.500975	valid_1's rmse: 0.502568
# [129]	training's rmse: 0.500938	valid_1's rmse: 0.502543
# [130]	training's rmse: 0.500863	valid_1's rmse: 0.502478
# [131]	training's rmse: 0.500834	valid_1's rmse: 0.502474
# [132]	training's rmse: 0.500807	valid_1's rmse: 0.502452
# [133]	training's rmse: 0.500768	valid_1's rmse: 0.502413
# [134]	training's rmse: 0.500724	valid_1's rmse: 0.502385
# [135]	training's rmse: 0.500679	valid_1's rmse: 0.502356
# [136]	training's rmse: 0.500657	valid_1's rmse: 0.502348
# [137]	training's rmse: 0.5006	valid_1's rmse: 0.502296
# [138]	training's rmse: 0.500562	valid_1's rmse: 0.502273
# [139]	training's rmse: 0.500477	valid_1's rmse: 0.502198
# [140]	training's rmse: 0.500447	valid_1's rmse: 0.502192
# [141]	training's rmse: 0.500412	valid_1's rmse: 0.502164
# [142]	training's rmse: 0.500372	valid_1's rmse: 0.502138
# [143]	training's rmse: 0.500333	valid_1's rmse: 0.502119
# [144]	training's rmse: 0.500272	valid_1's rmse: 0.502064
# [145]	training's rmse: 0.500219	valid_1's rmse: 0.502041
# [146]	training's rmse: 0.500182	valid_1's rmse: 0.502024
# [147]	training's rmse: 0.500139	valid_1's rmse: 0.502019
# [148]	training's rmse: 0.5001	valid_1's rmse: 0.502001
# [149]	training's rmse: 0.500072	valid_1's rmse: 0.501978
# [150]	training's rmse: 0.50004	valid_1's rmse: 0.501971
# [151]	training's rmse: 0.500018	valid_1's rmse: 0.501956
# [152]	training's rmse: 0.499985	valid_1's rmse: 0.501952
# [153]	training's rmse: 0.499959	valid_1's rmse: 0.501937
# [154]	training's rmse: 0.499929	valid_1's rmse: 0.501917
# [155]	training's rmse: 0.499906	valid_1's rmse: 0.501917
# [156]	training's rmse: 0.499877	valid_1's rmse: 0.501913
# [157]	training's rmse: 0.499846	valid_1's rmse: 0.501914
# [158]	training's rmse: 0.499795	valid_1's rmse: 0.501862
# [159]	training's rmse: 0.499783	valid_1's rmse: 0.501859
# [160]	training's rmse: 0.499735	valid_1's rmse: 0.501819
# [161]	training's rmse: 0.499698	valid_1's rmse: 0.501791
# [162]	training's rmse: 0.499666	valid_1's rmse: 0.501771
# [163]	training's rmse: 0.499607	valid_1's rmse: 0.501711
# [164]	training's rmse: 0.499579	valid_1's rmse: 0.501692
# [165]	training's rmse: 0.499552	valid_1's rmse: 0.501675
# [166]	training's rmse: 0.499524	valid_1's rmse: 0.50166
# [167]	training's rmse: 0.499501	valid_1's rmse: 0.501661
# [168]	training's rmse: 0.499483	valid_1's rmse: 0.501655
# [169]	training's rmse: 0.499462	valid_1's rmse: 0.501648
# [170]	training's rmse: 0.499428	valid_1's rmse: 0.501644
# [171]	training's rmse: 0.499403	valid_1's rmse: 0.501635
# [172]	training's rmse: 0.499321	valid_1's rmse: 0.501559
# [173]	training's rmse: 0.499289	valid_1's rmse: 0.501543
# [174]	training's rmse: 0.499278	valid_1's rmse: 0.501547
# [175]	training's rmse: 0.499239	valid_1's rmse: 0.501505
# [176]	training's rmse: 0.499215	valid_1's rmse: 0.501489
# [177]	training's rmse: 0.499194	valid_1's rmse: 0.501482
# [178]	training's rmse: 0.499155	valid_1's rmse: 0.501457
# [179]	training's rmse: 0.499145	valid_1's rmse: 0.501448
# [180]	training's rmse: 0.499127	valid_1's rmse: 0.501438
# [181]	training's rmse: 0.499119	valid_1's rmse: 0.501448
# [182]	training's rmse: 0.499105	valid_1's rmse: 0.501432
# [183]	training's rmse: 0.499057	valid_1's rmse: 0.501378
# [184]	training's rmse: 0.499016	valid_1's rmse: 0.501355
# [185]	training's rmse: 0.498984	valid_1's rmse: 0.501345
# [186]	training's rmse: 0.498918	valid_1's rmse: 0.501285
# [187]	training's rmse: 0.498898	valid_1's rmse: 0.501271
# [188]	training's rmse: 0.49888	valid_1's rmse: 0.501269
# [189]	training's rmse: 0.498853	valid_1's rmse: 0.50125
# [190]	training's rmse: 0.49884	valid_1's rmse: 0.501252
# [191]	training's rmse: 0.49882	valid_1's rmse: 0.501251
# [192]	training's rmse: 0.498787	valid_1's rmse: 0.501224
# [193]	training's rmse: 0.498772	valid_1's rmse: 0.501221
# [194]	training's rmse: 0.498746	valid_1's rmse: 0.501209
# [195]	training's rmse: 0.498715	valid_1's rmse: 0.501179
# [196]	training's rmse: 0.498686	valid_1's rmse: 0.501162
# [197]	training's rmse: 0.498649	valid_1's rmse: 0.501147
# [198]	training's rmse: 0.498617	valid_1's rmse: 0.50112
# [199]	training's rmse: 0.498571	valid_1's rmse: 0.501095
# [200]	training's rmse: 0.498543	valid_1's rmse: 0.501068
# [201]	training's rmse: 0.498527	valid_1's rmse: 0.501065
# [202]	training's rmse: 0.498501	valid_1's rmse: 0.501052
# [203]	training's rmse: 0.498411	valid_1's rmse: 0.500951
# [204]	training's rmse: 0.498365	valid_1's rmse: 0.500926
# [205]	training's rmse: 0.498331	valid_1's rmse: 0.500901
# [206]	training's rmse: 0.498307	valid_1's rmse: 0.500894
# [207]	training's rmse: 0.498295	valid_1's rmse: 0.500887
# [208]	training's rmse: 0.498276	valid_1's rmse: 0.500887
# [209]	training's rmse: 0.498256	valid_1's rmse: 0.500866
# [210]	training's rmse: 0.498241	valid_1's rmse: 0.500869
# [211]	training's rmse: 0.498216	valid_1's rmse: 0.500858
# [212]	training's rmse: 0.498179	valid_1's rmse: 0.500835
# [213]	training's rmse: 0.498157	valid_1's rmse: 0.500819
# [214]	training's rmse: 0.498127	valid_1's rmse: 0.500806
# [215]	training's rmse: 0.498112	valid_1's rmse: 0.5008
# [216]	training's rmse: 0.498092	valid_1's rmse: 0.500787
# [217]	training's rmse: 0.498036	valid_1's rmse: 0.500738
# [218]	training's rmse: 0.497996	valid_1's rmse: 0.500714
# [219]	training's rmse: 0.497974	valid_1's rmse: 0.500711
# [220]	training's rmse: 0.497955	valid_1's rmse: 0.500711
# [221]	training's rmse: 0.497933	valid_1's rmse: 0.500706
# [222]	training's rmse: 0.497909	valid_1's rmse: 0.500685
# [223]	training's rmse: 0.497905	valid_1's rmse: 0.500682
# [224]	training's rmse: 0.497878	valid_1's rmse: 0.500671
# [225]	training's rmse: 0.497844	valid_1's rmse: 0.500639
# [226]	training's rmse: 0.49782	valid_1's rmse: 0.500643
# [227]	training's rmse: 0.497793	valid_1's rmse: 0.500636
# [228]	training's rmse: 0.497762	valid_1's rmse: 0.500613
# [229]	training's rmse: 0.497734	valid_1's rmse: 0.500594
# [230]	training's rmse: 0.497716	valid_1's rmse: 0.500592
# [231]	training's rmse: 0.497682	valid_1's rmse: 0.500562
# [232]	training's rmse: 0.497655	valid_1's rmse: 0.500545
# [233]	training's rmse: 0.497636	valid_1's rmse: 0.500544
# [234]	training's rmse: 0.497613	valid_1's rmse: 0.500541
# [235]	training's rmse: 0.497578	valid_1's rmse: 0.50052
# [236]	training's rmse: 0.497555	valid_1's rmse: 0.500506
# [237]	training's rmse: 0.497514	valid_1's rmse: 0.500469
# [238]	training's rmse: 0.497494	valid_1's rmse: 0.500466
# [239]	training's rmse: 0.497473	valid_1's rmse: 0.500448
# [240]	training's rmse: 0.49745	valid_1's rmse: 0.500443
# [241]	training's rmse: 0.497392	valid_1's rmse: 0.500403
# [242]	training's rmse: 0.497315	valid_1's rmse: 0.500348
# [243]	training's rmse: 0.497299	valid_1's rmse: 0.500349
# [244]	training's rmse: 0.497284	valid_1's rmse: 0.50034
# [245]	training's rmse: 0.497264	valid_1's rmse: 0.500328
# [246]	training's rmse: 0.497247	valid_1's rmse: 0.500323
# [247]	training's rmse: 0.497223	valid_1's rmse: 0.500316
# [248]	training's rmse: 0.497202	valid_1's rmse: 0.500309
# [249]	training's rmse: 0.497193	valid_1's rmse: 0.500304
# [250]	training's rmse: 0.497157	valid_1's rmse: 0.500282
# [251]	training's rmse: 0.497138	valid_1's rmse: 0.500282
# [252]	training's rmse: 0.497116	valid_1's rmse: 0.500272
# [253]	training's rmse: 0.497087	valid_1's rmse: 0.500272
# [254]	training's rmse: 0.497062	valid_1's rmse: 0.500256
# [255]	training's rmse: 0.497045	valid_1's rmse: 0.500258
# [256]	training's rmse: 0.497022	valid_1's rmse: 0.500248
# [257]	training's rmse: 0.497	valid_1's rmse: 0.500243
# [258]	training's rmse: 0.496989	valid_1's rmse: 0.500234
# [259]	training's rmse: 0.496963	valid_1's rmse: 0.500225
# [260]	training's rmse: 0.496921	valid_1's rmse: 0.500214
# [261]	training's rmse: 0.496854	valid_1's rmse: 0.500143
# [262]	training's rmse: 0.496833	valid_1's rmse: 0.500135
# [263]	training's rmse: 0.496817	valid_1's rmse: 0.500134
# [264]	training's rmse: 0.496773	valid_1's rmse: 0.500092
# [265]	training's rmse: 0.496743	valid_1's rmse: 0.50008
# [266]	training's rmse: 0.496721	valid_1's rmse: 0.500074
# [267]	training's rmse: 0.496702	valid_1's rmse: 0.500067
# [268]	training's rmse: 0.496684	valid_1's rmse: 0.500057
# [269]	training's rmse: 0.496679	valid_1's rmse: 0.500063
# [270]	training's rmse: 0.49666	valid_1's rmse: 0.500054
# [271]	training's rmse: 0.496641	valid_1's rmse: 0.500041
# [272]	training's rmse: 0.49662	valid_1's rmse: 0.500053
# [273]	training's rmse: 0.496603	valid_1's rmse: 0.500035
# [274]	training's rmse: 0.496591	valid_1's rmse: 0.500032
# [275]	training's rmse: 0.496562	valid_1's rmse: 0.50002
# [276]	training's rmse: 0.496548	valid_1's rmse: 0.500011
# [277]	training's rmse: 0.496534	valid_1's rmse: 0.50001
# [278]	training's rmse: 0.496487	valid_1's rmse: 0.499968
# [279]	training's rmse: 0.496467	valid_1's rmse: 0.499954
# [280]	training's rmse: 0.496442	valid_1's rmse: 0.499943
# [281]	training's rmse: 0.496427	valid_1's rmse: 0.499925
# [282]	training's rmse: 0.496387	valid_1's rmse: 0.499897
# [283]	training's rmse: 0.496375	valid_1's rmse: 0.499887
# [284]	training's rmse: 0.496343	valid_1's rmse: 0.499851
# [285]	training's rmse: 0.496321	valid_1's rmse: 0.499852
# [286]	training's rmse: 0.49627	valid_1's rmse: 0.499821
# [287]	training's rmse: 0.496248	valid_1's rmse: 0.499825
# [288]	training's rmse: 0.496221	valid_1's rmse: 0.49982
# [289]	training's rmse: 0.496198	valid_1's rmse: 0.499806
# [290]	training's rmse: 0.496184	valid_1's rmse: 0.4998
# [291]	training's rmse: 0.496139	valid_1's rmse: 0.499763
# [292]	training's rmse: 0.496129	valid_1's rmse: 0.499758
# [293]	training's rmse: 0.496104	valid_1's rmse: 0.499743
# [294]	training's rmse: 0.496083	valid_1's rmse: 0.499744
# [295]	training's rmse: 0.496053	valid_1's rmse: 0.499726
# [296]	training's rmse: 0.496037	valid_1's rmse: 0.499741
# [297]	training's rmse: 0.496022	valid_1's rmse: 0.499749
# [298]	training's rmse: 0.496011	valid_1's rmse: 0.499745
# [299]	training's rmse: 0.495986	valid_1's rmse: 0.499728
# [300]	training's rmse: 0.495954	valid_1's rmse: 0.499702
# [301]	training's rmse: 0.495932	valid_1's rmse: 0.499687
# [302]	training's rmse: 0.495897	valid_1's rmse: 0.499652
# [303]	training's rmse: 0.495873	valid_1's rmse: 0.499638
# [304]	training's rmse: 0.495861	valid_1's rmse: 0.499656
# [305]	training's rmse: 0.495838	valid_1's rmse: 0.499644
# [306]	training's rmse: 0.495807	valid_1's rmse: 0.499628
# [307]	training's rmse: 0.495793	valid_1's rmse: 0.499636
# [308]	training's rmse: 0.495784	valid_1's rmse: 0.499638
# [309]	training's rmse: 0.495778	valid_1's rmse: 0.49964
# [310]	training's rmse: 0.495765	valid_1's rmse: 0.49964
# [311]	training's rmse: 0.495724	valid_1's rmse: 0.499605
# [312]	training's rmse: 0.495708	valid_1's rmse: 0.499606
# [313]	training's rmse: 0.495695	valid_1's rmse: 0.49959
# [314]	training's rmse: 0.495678	valid_1's rmse: 0.499592
# [315]	training's rmse: 0.495646	valid_1's rmse: 0.49959
# [316]	training's rmse: 0.495623	valid_1's rmse: 0.499579
# [317]	training's rmse: 0.495612	valid_1's rmse: 0.499581
# [318]	training's rmse: 0.495586	valid_1's rmse: 0.499562
# [319]	training's rmse: 0.49555	valid_1's rmse: 0.499541
# [320]	training's rmse: 0.495537	valid_1's rmse: 0.499545
# [321]	training's rmse: 0.495507	valid_1's rmse: 0.499522
# [322]	training's rmse: 0.495501	valid_1's rmse: 0.499522
# [323]	training's rmse: 0.49548	valid_1's rmse: 0.499507
# [324]	training's rmse: 0.49546	valid_1's rmse: 0.499507
# [325]	training's rmse: 0.495435	valid_1's rmse: 0.499492
# [326]	training's rmse: 0.495416	valid_1's rmse: 0.499481
# [327]	training's rmse: 0.495403	valid_1's rmse: 0.499495
# [328]	training's rmse: 0.49538	valid_1's rmse: 0.499487
# [329]	training's rmse: 0.49532	valid_1's rmse: 0.499441
# [330]	training's rmse: 0.495299	valid_1's rmse: 0.49943
# [331]	training's rmse: 0.495271	valid_1's rmse: 0.499427
# [332]	training's rmse: 0.495255	valid_1's rmse: 0.499421
# [333]	training's rmse: 0.495226	valid_1's rmse: 0.499399
# [334]	training's rmse: 0.495207	valid_1's rmse: 0.499388
# [335]	training's rmse: 0.495194	valid_1's rmse: 0.499388
# [336]	training's rmse: 0.495182	valid_1's rmse: 0.499382
# [337]	training's rmse: 0.495173	valid_1's rmse: 0.499379
# [338]	training's rmse: 0.495148	valid_1's rmse: 0.499354
# [339]	training's rmse: 0.495134	valid_1's rmse: 0.499349
# [340]	training's rmse: 0.495107	valid_1's rmse: 0.499337
# [341]	training's rmse: 0.495079	valid_1's rmse: 0.499315
# [342]	training's rmse: 0.495075	valid_1's rmse: 0.499318
# [343]	training's rmse: 0.495063	valid_1's rmse: 0.499318
# [344]	training's rmse: 0.495047	valid_1's rmse: 0.499325
# [345]	training's rmse: 0.495027	valid_1's rmse: 0.499321
# [346]	training's rmse: 0.49502	valid_1's rmse: 0.499314
# [347]	training's rmse: 0.495014	valid_1's rmse: 0.499311
# [348]	training's rmse: 0.495008	valid_1's rmse: 0.499315
# [349]	training's rmse: 0.494996	valid_1's rmse: 0.499314
# [350]	training's rmse: 0.494983	valid_1's rmse: 0.499321
# [351]	training's rmse: 0.494941	valid_1's rmse: 0.499299
# [352]	training's rmse: 0.494924	valid_1's rmse: 0.499293
# [353]	training's rmse: 0.494902	valid_1's rmse: 0.499286
# [354]	training's rmse: 0.494873	valid_1's rmse: 0.499273
# [355]	training's rmse: 0.49486	valid_1's rmse: 0.499261
# [356]	training's rmse: 0.49485	valid_1's rmse: 0.499257
# [357]	training's rmse: 0.494828	valid_1's rmse: 0.499237
# [358]	training's rmse: 0.494817	valid_1's rmse: 0.499224
# [359]	training's rmse: 0.494808	valid_1's rmse: 0.499221
# [360]	training's rmse: 0.494789	valid_1's rmse: 0.499204
# [361]	training's rmse: 0.494759	valid_1's rmse: 0.49919
# [362]	training's rmse: 0.494739	valid_1's rmse: 0.499185
# [363]	training's rmse: 0.494714	valid_1's rmse: 0.49917
# [364]	training's rmse: 0.494694	valid_1's rmse: 0.49915
# [365]	training's rmse: 0.494647	valid_1's rmse: 0.499119
# [366]	training's rmse: 0.494618	valid_1's rmse: 0.499109
# [367]	training's rmse: 0.494597	valid_1's rmse: 0.499101
# [368]	training's rmse: 0.494587	valid_1's rmse: 0.499103
# [369]	training's rmse: 0.494582	valid_1's rmse: 0.499102
# [370]	training's rmse: 0.494561	valid_1's rmse: 0.499089
# [371]	training's rmse: 0.494543	valid_1's rmse: 0.499089
# [372]	training's rmse: 0.494526	valid_1's rmse: 0.499085
# [373]	training's rmse: 0.494496	valid_1's rmse: 0.499079
# [374]	training's rmse: 0.494474	valid_1's rmse: 0.499075
# [375]	training's rmse: 0.494462	valid_1's rmse: 0.499085
# [376]	training's rmse: 0.494446	valid_1's rmse: 0.499082
# [377]	training's rmse: 0.494415	valid_1's rmse: 0.49906
# [378]	training's rmse: 0.494399	valid_1's rmse: 0.499046
# [379]	training's rmse: 0.494359	valid_1's rmse: 0.499011
# [380]	training's rmse: 0.494339	valid_1's rmse: 0.499008
# [381]	training's rmse: 0.494317	valid_1's rmse: 0.498995
# [382]	training's rmse: 0.494302	valid_1's rmse: 0.498996
# [383]	training's rmse: 0.494283	valid_1's rmse: 0.498987
# [384]	training's rmse: 0.494261	valid_1's rmse: 0.498975
# [385]	training's rmse: 0.494228	valid_1's rmse: 0.498955
# [386]	training's rmse: 0.494211	valid_1's rmse: 0.498956
# [387]	training's rmse: 0.494208	valid_1's rmse: 0.498959
# [388]	training's rmse: 0.494166	valid_1's rmse: 0.498922
# [389]	training's rmse: 0.494152	valid_1's rmse: 0.498924
# [390]	training's rmse: 0.494134	valid_1's rmse: 0.498918
# [391]	training's rmse: 0.49412	valid_1's rmse: 0.498922
# [392]	training's rmse: 0.494102	valid_1's rmse: 0.498928
# [393]	training's rmse: 0.494068	valid_1's rmse: 0.4989
# [394]	training's rmse: 0.494044	valid_1's rmse: 0.49887
# [395]	training's rmse: 0.494038	valid_1's rmse: 0.498864
# [396]	training's rmse: 0.494031	valid_1's rmse: 0.498856
# [397]	training's rmse: 0.49401	valid_1's rmse: 0.498851
# [398]	training's rmse: 0.494004	valid_1's rmse: 0.498855
# [399]	training's rmse: 0.493993	valid_1's rmse: 0.498859
# [400]	training's rmse: 0.493979	valid_1's rmse: 0.49887
# [401]	training's rmse: 0.493971	valid_1's rmse: 0.498875
# [402]	training's rmse: 0.493953	valid_1's rmse: 0.498877
# [403]	training's rmse: 0.493934	valid_1's rmse: 0.498867
# [404]	training's rmse: 0.493929	valid_1's rmse: 0.498871
# [405]	training's rmse: 0.493918	valid_1's rmse: 0.498872
# [406]	training's rmse: 0.493893	valid_1's rmse: 0.498848
# [407]	training's rmse: 0.49388	valid_1's rmse: 0.498848
# [408]	training's rmse: 0.493854	valid_1's rmse: 0.498836
# [409]	training's rmse: 0.493835	valid_1's rmse: 0.498835
# [410]	training's rmse: 0.493819	valid_1's rmse: 0.49882
# [411]	training's rmse: 0.493793	valid_1's rmse: 0.49881
# [412]	training's rmse: 0.493786	valid_1's rmse: 0.498805
# [413]	training's rmse: 0.493769	valid_1's rmse: 0.49879
# [414]	training's rmse: 0.49374	valid_1's rmse: 0.498771
# [415]	training's rmse: 0.49373	valid_1's rmse: 0.498769
# [416]	training's rmse: 0.493718	valid_1's rmse: 0.498785
# [417]	training's rmse: 0.493714	valid_1's rmse: 0.49879
# [418]	training's rmse: 0.493709	valid_1's rmse: 0.498784
# [419]	training's rmse: 0.493703	valid_1's rmse: 0.498781
# [420]	training's rmse: 0.493673	valid_1's rmse: 0.498773
# [421]	training's rmse: 0.493658	valid_1's rmse: 0.498772
# [422]	training's rmse: 0.493642	valid_1's rmse: 0.498775
# [423]	training's rmse: 0.493619	valid_1's rmse: 0.498756
# [424]	training's rmse: 0.493584	valid_1's rmse: 0.498747
# [425]	training's rmse: 0.493575	valid_1's rmse: 0.498742
# [426]	training's rmse: 0.493565	valid_1's rmse: 0.498748
# [427]	training's rmse: 0.493554	valid_1's rmse: 0.498748
# [428]	training's rmse: 0.493529	valid_1's rmse: 0.498741
# [429]	training's rmse: 0.493496	valid_1's rmse: 0.498724
# [430]	training's rmse: 0.493467	valid_1's rmse: 0.498717
# [431]	training's rmse: 0.493446	valid_1's rmse: 0.498722
# [432]	training's rmse: 0.493422	valid_1's rmse: 0.498705
# [433]	training's rmse: 0.493413	valid_1's rmse: 0.498709
# [434]	training's rmse: 0.49337	valid_1's rmse: 0.498657
# [435]	training's rmse: 0.493352	valid_1's rmse: 0.49864
# [436]	training's rmse: 0.493337	valid_1's rmse: 0.498639
# [437]	training's rmse: 0.493321	valid_1's rmse: 0.498626
# [438]	training's rmse: 0.493287	valid_1's rmse: 0.498604
# [439]	training's rmse: 0.493281	valid_1's rmse: 0.49861
# [440]	training's rmse: 0.493277	valid_1's rmse: 0.49861
# [441]	training's rmse: 0.493266	valid_1's rmse: 0.498613
# [442]	training's rmse: 0.493249	valid_1's rmse: 0.498605
# [443]	training's rmse: 0.493239	valid_1's rmse: 0.498599
# [444]	training's rmse: 0.493236	valid_1's rmse: 0.498603
# [445]	training's rmse: 0.493219	valid_1's rmse: 0.498627
# [446]	training's rmse: 0.493199	valid_1's rmse: 0.498611
# [447]	training's rmse: 0.493191	valid_1's rmse: 0.498605
# [448]	training's rmse: 0.493166	valid_1's rmse: 0.498579
# [449]	training's rmse: 0.493137	valid_1's rmse: 0.498598
# [450]	training's rmse: 0.493118	valid_1's rmse: 0.498586
# [451]	training's rmse: 0.4931	valid_1's rmse: 0.498571
# [452]	training's rmse: 0.493078	valid_1's rmse: 0.498558
# [453]	training's rmse: 0.493023	valid_1's rmse: 0.498515
# [454]	training's rmse: 0.493013	valid_1's rmse: 0.498515
# [455]	training's rmse: 0.493006	valid_1's rmse: 0.498516
# [456]	training's rmse: 0.492984	valid_1's rmse: 0.498516
# [457]	training's rmse: 0.49295	valid_1's rmse: 0.498499
# [458]	training's rmse: 0.492938	valid_1's rmse: 0.498492
# [459]	training's rmse: 0.492917	valid_1's rmse: 0.498477
# [460]	training's rmse: 0.4929	valid_1's rmse: 0.498485
# [461]	training's rmse: 0.492865	valid_1's rmse: 0.498466
# [462]	training's rmse: 0.492842	valid_1's rmse: 0.498456
# [463]	training's rmse: 0.492825	valid_1's rmse: 0.498446
# [464]	training's rmse: 0.492806	valid_1's rmse: 0.498424
# [465]	training's rmse: 0.492795	valid_1's rmse: 0.498417
# [466]	training's rmse: 0.492777	valid_1's rmse: 0.498416
# [467]	training's rmse: 0.492746	valid_1's rmse: 0.498375
# [468]	training's rmse: 0.492737	valid_1's rmse: 0.498376
# [469]	training's rmse: 0.492722	valid_1's rmse: 0.498367
# [470]	training's rmse: 0.492708	valid_1's rmse: 0.498375
# [471]	training's rmse: 0.4927	valid_1's rmse: 0.498375
# [472]	training's rmse: 0.492687	valid_1's rmse: 0.498361
# [473]	training's rmse: 0.492677	valid_1's rmse: 0.498359
# [474]	training's rmse: 0.49266	valid_1's rmse: 0.498349
# [475]	training's rmse: 0.492647	valid_1's rmse: 0.498351
# [476]	training's rmse: 0.492638	valid_1's rmse: 0.49835
# [477]	training's rmse: 0.492631	valid_1's rmse: 0.498355
# [478]	training's rmse: 0.49261	valid_1's rmse: 0.498351
# [479]	training's rmse: 0.492601	valid_1's rmse: 0.498358
# [480]	training's rmse: 0.492571	valid_1's rmse: 0.498348
# [481]	training's rmse: 0.49257	valid_1's rmse: 0.498351
# [482]	training's rmse: 0.492557	valid_1's rmse: 0.498351
# [483]	training's rmse: 0.492545	valid_1's rmse: 0.498355
# [484]	training's rmse: 0.49252	valid_1's rmse: 0.49834
# [485]	training's rmse: 0.49251	valid_1's rmse: 0.498339
# [486]	training's rmse: 0.4925	valid_1's rmse: 0.498339
# [487]	training's rmse: 0.492495	valid_1's rmse: 0.498349
# [488]	training's rmse: 0.492484	valid_1's rmse: 0.498344
# [489]	training's rmse: 0.492471	valid_1's rmse: 0.498332
# [490]	training's rmse: 0.492451	valid_1's rmse: 0.498322
# [491]	training's rmse: 0.492447	valid_1's rmse: 0.498322
# [492]	training's rmse: 0.492431	valid_1's rmse: 0.498335
# [493]	training's rmse: 0.492421	valid_1's rmse: 0.49833
# [494]	training's rmse: 0.492405	valid_1's rmse: 0.498327
# [495]	training's rmse: 0.492359	valid_1's rmse: 0.498302
# [496]	training's rmse: 0.492354	valid_1's rmse: 0.4983
# [497]	training's rmse: 0.492348	valid_1's rmse: 0.498306
# [498]	training's rmse: 0.492339	valid_1's rmse: 0.498304
# [499]	training's rmse: 0.492327	valid_1's rmse: 0.498304
# [500]	training's rmse: 0.492312	valid_1's rmse: 0.498301
# [501]	training's rmse: 0.492296	valid_1's rmse: 0.49829
# [502]	training's rmse: 0.492284	valid_1's rmse: 0.498281
# [503]	training's rmse: 0.49227	valid_1's rmse: 0.498275
# [504]	training's rmse: 0.492257	valid_1's rmse: 0.498275
# [505]	training's rmse: 0.492243	valid_1's rmse: 0.498271
# [506]	training's rmse: 0.492237	valid_1's rmse: 0.49828
# [507]	training's rmse: 0.49223	valid_1's rmse: 0.498278
# [508]	training's rmse: 0.492216	valid_1's rmse: 0.498276
# [509]	training's rmse: 0.492206	valid_1's rmse: 0.49827
# [510]	training's rmse: 0.49219	valid_1's rmse: 0.498266
# [511]	training's rmse: 0.49218	valid_1's rmse: 0.498267
# [512]	training's rmse: 0.492166	valid_1's rmse: 0.498258
# [513]	training's rmse: 0.492152	valid_1's rmse: 0.498256
# [514]	training's rmse: 0.492136	valid_1's rmse: 0.498241
# [515]	training's rmse: 0.492131	valid_1's rmse: 0.49824
# [516]	training's rmse: 0.492101	valid_1's rmse: 0.498226
# [517]	training's rmse: 0.492091	valid_1's rmse: 0.498238
# [518]	training's rmse: 0.492065	valid_1's rmse: 0.498231
# [519]	training's rmse: 0.492056	valid_1's rmse: 0.498242
# [520]	training's rmse: 0.492043	valid_1's rmse: 0.498248
# [521]	training's rmse: 0.492026	valid_1's rmse: 0.498243
# [522]	training's rmse: 0.492015	valid_1's rmse: 0.498246
# [523]	training's rmse: 0.492003	valid_1's rmse: 0.49824
# [524]	training's rmse: 0.492	valid_1's rmse: 0.498241
# [525]	training's rmse: 0.491996	valid_1's rmse: 0.498235
# [526]	training's rmse: 0.491985	valid_1's rmse: 0.498231
# [527]	training's rmse: 0.491968	valid_1's rmse: 0.498213
# [528]	training's rmse: 0.49194	valid_1's rmse: 0.498194
# [529]	training's rmse: 0.491925	valid_1's rmse: 0.498195
# [530]	training's rmse: 0.49191	valid_1's rmse: 0.498185
# [531]	training's rmse: 0.491901	valid_1's rmse: 0.498177
# [532]	training's rmse: 0.49189	valid_1's rmse: 0.498173
# [533]	training's rmse: 0.49185	valid_1's rmse: 0.49814
# [534]	training's rmse: 0.491836	valid_1's rmse: 0.498146
# [535]	training's rmse: 0.491827	valid_1's rmse: 0.498146
# [536]	training's rmse: 0.49181	valid_1's rmse: 0.49813
# [537]	training's rmse: 0.4918	valid_1's rmse: 0.498129
# [538]	training's rmse: 0.491788	valid_1's rmse: 0.498125
# [539]	training's rmse: 0.49178	valid_1's rmse: 0.498135
# [540]	training's rmse: 0.491772	valid_1's rmse: 0.498136
# [541]	training's rmse: 0.491765	valid_1's rmse: 0.498141
# [542]	training's rmse: 0.491754	valid_1's rmse: 0.498144
# [543]	training's rmse: 0.491746	valid_1's rmse: 0.498144
# [544]	training's rmse: 0.491736	valid_1's rmse: 0.498132
# [545]	training's rmse: 0.491727	valid_1's rmse: 0.498144
# [546]	training's rmse: 0.491707	valid_1's rmse: 0.498132
# [547]	training's rmse: 0.491696	valid_1's rmse: 0.498123
# [548]	training's rmse: 0.491674	valid_1's rmse: 0.498106
# [549]	training's rmse: 0.491669	valid_1's rmse: 0.498114
# [550]	training's rmse: 0.49166	valid_1's rmse: 0.498122
# [551]	training's rmse: 0.491648	valid_1's rmse: 0.498123
# [552]	training's rmse: 0.491639	valid_1's rmse: 0.498122
# [553]	training's rmse: 0.491635	valid_1's rmse: 0.498117
# [554]	training's rmse: 0.491624	valid_1's rmse: 0.498122
# [555]	training's rmse: 0.491609	valid_1's rmse: 0.498113
# [556]	training's rmse: 0.491596	valid_1's rmse: 0.498117
# [557]	training's rmse: 0.491587	valid_1's rmse: 0.498119
# [558]	training's rmse: 0.49158	valid_1's rmse: 0.498117
# [559]	training's rmse: 0.491576	valid_1's rmse: 0.498123
# [560]	training's rmse: 0.49157	valid_1's rmse: 0.498128
# [561]	training's rmse: 0.491555	valid_1's rmse: 0.498116
# [562]	training's rmse: 0.491545	valid_1's rmse: 0.498127
# [563]	training's rmse: 0.491535	valid_1's rmse: 0.498131
# [564]	training's rmse: 0.491507	valid_1's rmse: 0.498111
# [565]	training's rmse: 0.4915	valid_1's rmse: 0.498112
# [566]	training's rmse: 0.491491	valid_1's rmse: 0.498122
# [567]	training's rmse: 0.491477	valid_1's rmse: 0.498124
# [568]	training's rmse: 0.491453	valid_1's rmse: 0.498103
# [569]	training's rmse: 0.49143	valid_1's rmse: 0.498083
# [570]	training's rmse: 0.491425	valid_1's rmse: 0.498082
# [571]	training's rmse: 0.491392	valid_1's rmse: 0.498053
# [572]	training's rmse: 0.491386	valid_1's rmse: 0.498057
# [573]	training's rmse: 0.491375	valid_1's rmse: 0.498065
# [574]	training's rmse: 0.491342	valid_1's rmse: 0.498046
# [575]	training's rmse: 0.491328	valid_1's rmse: 0.498033
# [576]	training's rmse: 0.491316	valid_1's rmse: 0.498027
# [577]	training's rmse: 0.491299	valid_1's rmse: 0.498032
# [578]	training's rmse: 0.491292	valid_1's rmse: 0.498034
# [579]	training's rmse: 0.491281	valid_1's rmse: 0.498024
# [580]	training's rmse: 0.491276	valid_1's rmse: 0.498019
# [581]	training's rmse: 0.491246	valid_1's rmse: 0.498004
# [582]	training's rmse: 0.491234	valid_1's rmse: 0.497998
# [583]	training's rmse: 0.491224	valid_1's rmse: 0.498003
# [584]	training's rmse: 0.49121	valid_1's rmse: 0.497992
# [585]	training's rmse: 0.491199	valid_1's rmse: 0.498006
# [586]	training's rmse: 0.491186	valid_1's rmse: 0.498004
# [587]	training's rmse: 0.49117	valid_1's rmse: 0.498013
# [588]	training's rmse: 0.491161	valid_1's rmse: 0.498016
# [589]	training's rmse: 0.491149	valid_1's rmse: 0.498014
# [590]	training's rmse: 0.491138	valid_1's rmse: 0.498012
# [591]	training's rmse: 0.491124	valid_1's rmse: 0.498008
# [592]	training's rmse: 0.491104	valid_1's rmse: 0.498002
# [593]	training's rmse: 0.491089	valid_1's rmse: 0.497996
# [594]	training's rmse: 0.491064	valid_1's rmse: 0.497983
# [595]	training's rmse: 0.49105	valid_1's rmse: 0.497986
# [596]	training's rmse: 0.491034	valid_1's rmse: 0.49798
# [597]	training's rmse: 0.491014	valid_1's rmse: 0.497978
# [598]	training's rmse: 0.490994	valid_1's rmse: 0.49798
# [599]	training's rmse: 0.490984	valid_1's rmse: 0.497982
# [600]	training's rmse: 0.490958	valid_1's rmse: 0.497958
# [601]	training's rmse: 0.490949	valid_1's rmse: 0.497955
# [602]	training's rmse: 0.490935	valid_1's rmse: 0.497951
# [603]	training's rmse: 0.490921	valid_1's rmse: 0.497962
# [604]	training's rmse: 0.490892	valid_1's rmse: 0.497944
# [605]	training's rmse: 0.490879	valid_1's rmse: 0.497938
# [606]	training's rmse: 0.490863	valid_1's rmse: 0.49793
# [607]	training's rmse: 0.49085	valid_1's rmse: 0.497931
# [608]	training's rmse: 0.490814	valid_1's rmse: 0.497908
# [609]	training's rmse: 0.490804	valid_1's rmse: 0.49791
# [610]	training's rmse: 0.490794	valid_1's rmse: 0.497917
# [611]	training's rmse: 0.490786	valid_1's rmse: 0.497919
# [612]	training's rmse: 0.490768	valid_1's rmse: 0.497914
# [613]	training's rmse: 0.49076	valid_1's rmse: 0.497923
# [614]	training's rmse: 0.490736	valid_1's rmse: 0.497914
# [615]	training's rmse: 0.490726	valid_1's rmse: 0.497903
# [616]	training's rmse: 0.490717	valid_1's rmse: 0.497895
# [617]	training's rmse: 0.490709	valid_1's rmse: 0.497892
# [618]	training's rmse: 0.49069	valid_1's rmse: 0.497878
# [619]	training's rmse: 0.490671	valid_1's rmse: 0.497872
# [620]	training's rmse: 0.49065	valid_1's rmse: 0.497872
# [621]	training's rmse: 0.490644	valid_1's rmse: 0.497884
# [622]	training's rmse: 0.49063	valid_1's rmse: 0.497889
# [623]	training's rmse: 0.490616	valid_1's rmse: 0.497881
# [624]	training's rmse: 0.49061	valid_1's rmse: 0.497887
# [625]	training's rmse: 0.490589	valid_1's rmse: 0.497869
# [626]	training's rmse: 0.490583	valid_1's rmse: 0.497872
# [627]	training's rmse: 0.490554	valid_1's rmse: 0.497849
# [628]	training's rmse: 0.490538	valid_1's rmse: 0.497855
# [629]	training's rmse: 0.490519	valid_1's rmse: 0.497871
# [630]	training's rmse: 0.490496	valid_1's rmse: 0.497855
# [631]	training's rmse: 0.490488	valid_1's rmse: 0.497864
# [632]	training's rmse: 0.490476	valid_1's rmse: 0.497861
# [633]	training's rmse: 0.490463	valid_1's rmse: 0.49785
# [634]	training's rmse: 0.490454	valid_1's rmse: 0.497852
# [635]	training's rmse: 0.490436	valid_1's rmse: 0.497842
# [636]	training's rmse: 0.490423	valid_1's rmse: 0.497846
# [637]	training's rmse: 0.490411	valid_1's rmse: 0.497848
# [638]	training's rmse: 0.490401	valid_1's rmse: 0.497841
# [639]	training's rmse: 0.490385	valid_1's rmse: 0.497839
# [640]	training's rmse: 0.490376	valid_1's rmse: 0.497837
# [641]	training's rmse: 0.490372	valid_1's rmse: 0.497844
# [642]	training's rmse: 0.490361	valid_1's rmse: 0.497847
# [643]	training's rmse: 0.490351	valid_1's rmse: 0.497845
# [644]	training's rmse: 0.490335	valid_1's rmse: 0.497848
# [645]	training's rmse: 0.49032	valid_1's rmse: 0.497857
# [646]	training's rmse: 0.490309	valid_1's rmse: 0.497852
# [647]	training's rmse: 0.490298	valid_1's rmse: 0.497842
# [648]	training's rmse: 0.490262	valid_1's rmse: 0.497814
# [649]	training's rmse: 0.490249	valid_1's rmse: 0.497809
# [650]	training's rmse: 0.490235	valid_1's rmse: 0.497802
# [651]	training's rmse: 0.490221	valid_1's rmse: 0.497799
# [652]	training's rmse: 0.490208	valid_1's rmse: 0.497805
# [653]	training's rmse: 0.490192	valid_1's rmse: 0.497802
# [654]	training's rmse: 0.490187	valid_1's rmse: 0.49782
# [655]	training's rmse: 0.490165	valid_1's rmse: 0.497807
# [656]	training's rmse: 0.490156	valid_1's rmse: 0.497805
# [657]	training's rmse: 0.49015	valid_1's rmse: 0.497805
# [658]	training's rmse: 0.490137	valid_1's rmse: 0.497801
# [659]	training's rmse: 0.490129	valid_1's rmse: 0.497792
# [660]	training's rmse: 0.490121	valid_1's rmse: 0.497799
# [661]	training's rmse: 0.490119	valid_1's rmse: 0.497796
# [662]	training's rmse: 0.490072	valid_1's rmse: 0.497781
# [663]	training's rmse: 0.490053	valid_1's rmse: 0.497779
# [664]	training's rmse: 0.490036	valid_1's rmse: 0.497776
# [665]	training's rmse: 0.490023	valid_1's rmse: 0.497771
# [666]	training's rmse: 0.490018	valid_1's rmse: 0.497773
# [667]	training's rmse: 0.490007	valid_1's rmse: 0.49778
# [668]	training's rmse: 0.490001	valid_1's rmse: 0.497794
# [669]	training's rmse: 0.48999	valid_1's rmse: 0.497796
# [670]	training's rmse: 0.489986	valid_1's rmse: 0.4978
# [671]	training's rmse: 0.489972	valid_1's rmse: 0.497791
# [672]	training's rmse: 0.489951	valid_1's rmse: 0.497784
# [673]	training's rmse: 0.489941	valid_1's rmse: 0.49779
# [674]	training's rmse: 0.48993	valid_1's rmse: 0.497789
# [675]	training's rmse: 0.489914	valid_1's rmse: 0.497785
# [676]	training's rmse: 0.489908	valid_1's rmse: 0.49778
# [677]	training's rmse: 0.489889	valid_1's rmse: 0.497792
# [678]	training's rmse: 0.489876	valid_1's rmse: 0.497798
# [679]	training's rmse: 0.489855	valid_1's rmse: 0.497794
# [680]	training's rmse: 0.48984	valid_1's rmse: 0.497795
# [681]	training's rmse: 0.489829	valid_1's rmse: 0.497791
# [682]	training's rmse: 0.489824	valid_1's rmse: 0.497789
# [683]	training's rmse: 0.489817	valid_1's rmse: 0.49779
# [684]	training's rmse: 0.489797	valid_1's rmse: 0.497772
# [685]	training's rmse: 0.48979	valid_1's rmse: 0.49777
# [686]	training's rmse: 0.489783	valid_1's rmse: 0.49777
# [687]	training's rmse: 0.489777	valid_1's rmse: 0.497777
# [688]	training's rmse: 0.489764	valid_1's rmse: 0.49778
# [689]	training's rmse: 0.489754	valid_1's rmse: 0.497784
# [690]	training's rmse: 0.489742	valid_1's rmse: 0.497785
# [691]	training's rmse: 0.489734	valid_1's rmse: 0.497787
# [692]	training's rmse: 0.489715	valid_1's rmse: 0.497774
# [693]	training's rmse: 0.489704	valid_1's rmse: 0.497776
# [694]	training's rmse: 0.489686	valid_1's rmse: 0.497761
# [695]	training's rmse: 0.489675	valid_1's rmse: 0.497764
# [696]	training's rmse: 0.489666	valid_1's rmse: 0.497764
# [697]	training's rmse: 0.489657	valid_1's rmse: 0.497771
# [698]	training's rmse: 0.489645	valid_1's rmse: 0.497777
# [699]	training's rmse: 0.489631	valid_1's rmse: 0.497777
# [700]	training's rmse: 0.489611	valid_1's rmse: 0.497761
# [701]	training's rmse: 0.489598	valid_1's rmse: 0.497761
# [702]	training's rmse: 0.48959	valid_1's rmse: 0.497756
# [703]	training's rmse: 0.489583	valid_1's rmse: 0.497756
# [704]	training's rmse: 0.489568	valid_1's rmse: 0.497746
# [705]	training's rmse: 0.489565	valid_1's rmse: 0.497748
# [706]	training's rmse: 0.489554	valid_1's rmse: 0.49775
# [707]	training's rmse: 0.489543	valid_1's rmse: 0.497751
# [708]	training's rmse: 0.48952	valid_1's rmse: 0.497721
# [709]	training's rmse: 0.489508	valid_1's rmse: 0.497716
# [710]	training's rmse: 0.489504	valid_1's rmse: 0.497718
# [711]	training's rmse: 0.489498	valid_1's rmse: 0.497715
# [712]	training's rmse: 0.489474	valid_1's rmse: 0.497686
# [713]	training's rmse: 0.489458	valid_1's rmse: 0.497687
# [714]	training's rmse: 0.489447	valid_1's rmse: 0.497679
# [715]	training's rmse: 0.489429	valid_1's rmse: 0.497675
# [716]	training's rmse: 0.489418	valid_1's rmse: 0.497669
# [717]	training's rmse: 0.489404	valid_1's rmse: 0.497667
# [718]	training's rmse: 0.489396	valid_1's rmse: 0.497668
# [719]	training's rmse: 0.489383	valid_1's rmse: 0.497667
# [720]	training's rmse: 0.489363	valid_1's rmse: 0.497654
# [721]	training's rmse: 0.489351	valid_1's rmse: 0.497655
# [722]	training's rmse: 0.489348	valid_1's rmse: 0.49766
# [723]	training's rmse: 0.489341	valid_1's rmse: 0.497664
# [724]	training's rmse: 0.489329	valid_1's rmse: 0.497666
# [725]	training's rmse: 0.489304	valid_1's rmse: 0.497656
# [726]	training's rmse: 0.489296	valid_1's rmse: 0.497654
# [727]	training's rmse: 0.48927	valid_1's rmse: 0.497632
# [728]	training's rmse: 0.489251	valid_1's rmse: 0.497616
# [729]	training's rmse: 0.489247	valid_1's rmse: 0.497614
# [730]	training's rmse: 0.489237	valid_1's rmse: 0.497627
# [731]	training's rmse: 0.489224	valid_1's rmse: 0.497627
# [732]	training's rmse: 0.489212	valid_1's rmse: 0.497635
# [733]	training's rmse: 0.489204	valid_1's rmse: 0.497641
# [734]	training's rmse: 0.489195	valid_1's rmse: 0.497635
# [735]	training's rmse: 0.489186	valid_1's rmse: 0.497637
# [736]	training's rmse: 0.489178	valid_1's rmse: 0.497631
# [737]	training's rmse: 0.489172	valid_1's rmse: 0.497637
# [738]	training's rmse: 0.489157	valid_1's rmse: 0.497638
# [739]	training's rmse: 0.48915	valid_1's rmse: 0.497646
# [740]	training's rmse: 0.489131	valid_1's rmse: 0.497636
# [741]	training's rmse: 0.489128	valid_1's rmse: 0.497637
# [742]	training's rmse: 0.489119	valid_1's rmse: 0.497638
# [743]	training's rmse: 0.489113	valid_1's rmse: 0.497635
# [744]	training's rmse: 0.489105	valid_1's rmse: 0.497636
# [745]	training's rmse: 0.489076	valid_1's rmse: 0.497625
# [746]	training's rmse: 0.489067	valid_1's rmse: 0.497621
# [747]	training's rmse: 0.489052	valid_1's rmse: 0.497601
# [748]	training's rmse: 0.489038	valid_1's rmse: 0.497602
# [749]	training's rmse: 0.489035	valid_1's rmse: 0.497604
# [750]	training's rmse: 0.489029	valid_1's rmse: 0.497614
# [751]	training's rmse: 0.489015	valid_1's rmse: 0.49763
# [752]	training's rmse: 0.489008	valid_1's rmse: 0.497623
# [753]	training's rmse: 0.489004	valid_1's rmse: 0.497629
# [754]	training's rmse: 0.488993	valid_1's rmse: 0.497625
# [755]	training's rmse: 0.488987	valid_1's rmse: 0.497635
# [756]	training's rmse: 0.488965	valid_1's rmse: 0.49763
# [757]	training's rmse: 0.488957	valid_1's rmse: 0.497625
# [758]	training's rmse: 0.488952	valid_1's rmse: 0.497622
# [759]	training's rmse: 0.488939	valid_1's rmse: 0.497615
# [760]	training's rmse: 0.488931	valid_1's rmse: 0.497616
# [761]	training's rmse: 0.488919	valid_1's rmse: 0.497617
# [762]	training's rmse: 0.488912	valid_1's rmse: 0.497618
# [763]	training's rmse: 0.488899	valid_1's rmse: 0.497625
# [764]	training's rmse: 0.488882	valid_1's rmse: 0.497614
# [765]	training's rmse: 0.488863	valid_1's rmse: 0.497608
# [766]	training's rmse: 0.488854	valid_1's rmse: 0.497603
# [767]	training's rmse: 0.488828	valid_1's rmse: 0.497587
# [768]	training's rmse: 0.488824	valid_1's rmse: 0.497585
# [769]	training's rmse: 0.488814	valid_1's rmse: 0.497584
# [770]	training's rmse: 0.488809	valid_1's rmse: 0.497604
# [771]	training's rmse: 0.488796	valid_1's rmse: 0.497604
# [772]	training's rmse: 0.488773	valid_1's rmse: 0.497592
# [773]	training's rmse: 0.488769	valid_1's rmse: 0.497595
# [774]	training's rmse: 0.488764	valid_1's rmse: 0.497599
# [775]	training's rmse: 0.488753	valid_1's rmse: 0.497587
# [776]	training's rmse: 0.488749	valid_1's rmse: 0.497578
# [777]	training's rmse: 0.48874	valid_1's rmse: 0.497567
# [778]	training's rmse: 0.488729	valid_1's rmse: 0.497559
# [779]	training's rmse: 0.488721	valid_1's rmse: 0.497562
# [780]	training's rmse: 0.488712	valid_1's rmse: 0.497554
# [781]	training's rmse: 0.4887	valid_1's rmse: 0.497554
# [782]	training's rmse: 0.488692	valid_1's rmse: 0.497558
# [783]	training's rmse: 0.488686	valid_1's rmse: 0.497559
# [784]	training's rmse: 0.488672	valid_1's rmse: 0.497557
# [785]	training's rmse: 0.488662	valid_1's rmse: 0.497563
# [786]	training's rmse: 0.488643	valid_1's rmse: 0.497553
# [787]	training's rmse: 0.488628	valid_1's rmse: 0.49754
# [788]	training's rmse: 0.488621	valid_1's rmse: 0.497552
# [789]	training's rmse: 0.488602	valid_1's rmse: 0.497542
# [790]	training's rmse: 0.488593	valid_1's rmse: 0.49754
# [791]	training's rmse: 0.488586	valid_1's rmse: 0.497541
# [792]	training's rmse: 0.488578	valid_1's rmse: 0.497535
# [793]	training's rmse: 0.488571	valid_1's rmse: 0.49753
# [794]	training's rmse: 0.488557	valid_1's rmse: 0.497527
# [795]	training's rmse: 0.488547	valid_1's rmse: 0.497531
# [796]	training's rmse: 0.488533	valid_1's rmse: 0.497528
# [797]	training's rmse: 0.488509	valid_1's rmse: 0.497514
# [798]	training's rmse: 0.488504	valid_1's rmse: 0.497524
# [799]	training's rmse: 0.488494	valid_1's rmse: 0.49751
# [800]	training's rmse: 0.488477	valid_1's rmse: 0.49751
# [801]	training's rmse: 0.488467	valid_1's rmse: 0.497514
# [802]	training's rmse: 0.48846	valid_1's rmse: 0.49753
# [803]	training's rmse: 0.488455	valid_1's rmse: 0.497532
# [804]	training's rmse: 0.488447	valid_1's rmse: 0.497536
# [805]	training's rmse: 0.488436	valid_1's rmse: 0.497534
# [806]	training's rmse: 0.488435	valid_1's rmse: 0.497539
# [807]	training's rmse: 0.488422	valid_1's rmse: 0.497539
# [808]	training's rmse: 0.488413	valid_1's rmse: 0.497545
# [809]	training's rmse: 0.488398	valid_1's rmse: 0.497535
# [810]	training's rmse: 0.488387	valid_1's rmse: 0.497539
# [811]	training's rmse: 0.488381	valid_1's rmse: 0.497541
# [812]	training's rmse: 0.488375	valid_1's rmse: 0.49755
# [813]	training's rmse: 0.488368	valid_1's rmse: 0.497549
# [814]	training's rmse: 0.488358	valid_1's rmse: 0.497554
# [815]	training's rmse: 0.488354	valid_1's rmse: 0.497554
# [816]	training's rmse: 0.488329	valid_1's rmse: 0.497534
# [817]	training's rmse: 0.488322	valid_1's rmse: 0.497528
# [818]	training's rmse: 0.488318	valid_1's rmse: 0.497532
# [819]	training's rmse: 0.488294	valid_1's rmse: 0.497517
# Early stopping, best iteration is:
# [799]	training's rmse: 0.488494	valid_1's rmse: 0.49751

# %%
imp_df = pd.DataFrame([lgbm.feature_importance()], 
                      columns=feature_columns, 
                      index=['importance']).T.sort_values(by='importance', ascending=False)
imp_df
# Out:
#                                              importance
# visit_month                                         853
# air_store_id-visit_dayofweek-visitors_avg           794
# air_store_id-visit_dayofweek-visitors_max           710
# visit_month-visitors_avg                            698
# air_store_id-visitors_max                           644
# air_store_id-visit_dayofweek-visitors_q25           637
# visit_month-visitors_max                            563
# total_reserve_visitors                              528
# air_store_id-visit_dayofweek-visitors_q75           518
# air_store_id-visitors_avg                           428
# holiday_flg                                         413
# air_store_id-visitors_q75                           405
# air_store_id-visit_dayofweek-visitors_q50           405
# latitude                                            404
# air_store_id-visitors_q25                           384
# ahead_reserve_hours_median                          354
# air_genre_name-air_area_name-visitors_max           320
# longitude                                           284
# air_genre_name-air_area_name-visitors_avg           284
# air_area_name-visit_dayofweek-visitors_avg          279
# air_store_id-visit_dayofweek-visitors_min           277
# air_area_name-visit_dayofweek-visitors_max          266
# air_genre_name-visit_dayofweek-visitors_max         266
# visit_days_in_month                                 262
# air_genre_name-visit_dayofweek-visitors_avg         247
# air_area_name-visit_dayofweek-visitors_q75          244
# air_store_id-visitors_q50                           214
# air_area_name-visitors_avg                          205
# air_area_name-visitors_max                          204
# reserve_in_30day_visitors                           187
# ...                                                 ...
# visit_month-visitors_q50                             33
# air_genre_name_Italian/French                        25
# air_genre_name_Japanese food                         25
# reserve_in_2day_count                                23
# air_genre_name_Dining bar                            23
# air_genre_name_Karaoke/Party                         22
# air_genre_name_Izakaya                               22
# air_genre_name_Bar/Cocktail                          21
# reserve_in_3day_count                                20
# air_genre_name-visitors_q75                          19
# air_genre_name_Western food                          18
# visit_dayofweek-visitors_q25                         16
# visit_month-visitors_q25                             15
# air_genre_name_Other                                 15
# air_area_name-visit_dayofweek-visitors_min           10
# visit_dayofweek-visitors_q75                         10
# air_genre_name_Yakiniku/Korean food                   9
# air_genre_name-visitors_q25                           8
# air_genre_name_Creative cuisine                       8
# air_genre_name_Okonomiyaki/Monja/Teppanyaki           7
# air_genre_name-visitors_q50                           7
# air_area_name-visitors_min                            6
# air_genre_name-visit_dayofweek-visitors_min           6
# visit_dayofweek-visitors_q50                          3
# air_genre_name-air_area_name-visitors_min             2
# air_genre_name_Asian                                  2
# air_genre_name-visitors_min                           0
# visit_month-visitors_min                              0
# visit_dayofweek-visitors_min                          0
# air_genre_name_International cuisine                  0
#
# [87 rows x 1 columns]

# %% [markdown]
# ## predict

# %%
pred_df = pd.DataFrame({
    'lgbm': lgbm.predict(X_tst),
})

# %%
pred_df
# Out:
#            lgbm
# 0      0.900769
# 1      3.024311
# 2      3.119990
# 3      3.322663
# 4      3.432096
# 5      3.624016
# 6      2.653887
# 7      0.900769
# 8      3.076241
# 9      3.176332
# 10     3.386657
# 11     3.459360
# 12     3.521244
# 13     2.507789
# 14     0.973131
# 15     3.076241
# 16     3.176332
# 17     3.353185
# 18     3.443192
# 19     3.619246
# 20     2.507789
# 21     0.973131
# 22     3.076241
# 23     3.176332
# 24     3.353185
# 25     3.443192
# 26     3.619246
# 27     2.507789
# 28     0.973131
# 29     3.076241
# ...         ...
# 31989  1.639697
# 31990  1.949743
# 31991  1.833472
# 31992  1.925493
# 31993  2.076403
# 31994  1.523196
# 31995  1.526407
# 31996  1.639697
# 31997  1.651820
# 31998  1.635460
# 31999  1.790271
# 32000  2.076403
# 32001  1.523196
# 32002  1.526407
# 32003  1.639697
# 32004  1.651820
# 32005  1.635460
# 32006  1.790271
# 32007  2.076403
# 32008  1.523196
# 32009  1.526407
# 32010  1.639697
# 32011  1.651820
# 32012  1.635460
# 32013  1.790271
# 32014  2.076403
# 32015  1.523196
# 32016  1.526407
# 32017  1.639697
# 32018  1.651820
#
# [32019 rows x 1 columns]

# %%
pred_res = pred_df.mean(axis=1)
pred_res = pred_res.apply(np.expm1)
# test
pred_res = pred_res.apply(lambda x: np.around(x, 1))

# %%
res_df = pd.DataFrame({
    output_id_col: tst_df[output_id_col].values,
    output_label_col: pred_res,
})
res_df[[output_id_col, output_label_col]].to_csv(submission_path, index=False)
