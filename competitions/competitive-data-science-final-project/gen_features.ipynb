# %% [markdown]
# Creating all pair in (shop_id, item_id) for each date_block_num. And if row has not item_count from origin sales data, item_count will fill 0.

# %%
# coding: utf-8
import os
from itertools import product

import pandas as pd
import numpy as np
import scipy
import lightgbm as lgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import metrics
from sklearn import model_selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn import preprocessing
from sklearn.linear_model import ElasticNet, ElasticNetCV
from sklearn.linear_model import LinearRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from IPython.display import display

from mydatools.features_generate import features_save

% matplotlib inline

# %% [markdown]
# ## Config

# %%
# trn_path = './data/input/train.csv'
tst_path = './data/input/test.csv'
id_col = 'ID'
label_col = 'item_cnt_month'

submission_path = './data/output/submission/stacking_simple.csv'
output_id_col = id_col
output_label_col = label_col

# %% [markdown]
# ## Load Data

# %%
item_cate_df = pd.read_csv('./data/input/item_categories.csv')
item_df = pd.read_csv('./data/input/items.csv')
sales_df = pd.read_csv('./data/input/sales_train.csv')
shop_df = pd.read_csv('./data/input/shops.csv')

# %%
sales_df['revenue'] = sales_df['item_price'] * sales_df['item_cnt_day']
trn_df = sales_df.groupby(['shop_id', 'item_id', 'date_block_num'])['item_cnt_day'].sum().reset_index()
trn_df = trn_df.rename(columns={'item_cnt_day': 'item_cnt_month'})
trn_df['ID'] = 0
# trn_df['ds_type'] = 'trn'

tst_df = pd.read_csv(tst_path)
tst_df['date_block_num'] = 34
tst_df['item_cnt_month'] = 0
# tst_df['ds_type'] = 'tst'

full_df = pd.concat([trn_df, tst_df])
full_df.head()
# Out:
#    ID  date_block_num  item_cnt_month  item_id  shop_id
# 0   0               1            31.0       30        0
# 1   0               1            11.0       31        0
# 2   0               0             6.0       32        0
# 3   0               1            10.0       32        0
# 4   0               0             3.0       33        0

# %% [markdown]
# ## Get grid
#
# (shop_id, item_id) for each date_block_num

# %%
index_cols = ['shop_id', 'item_id', 'date_block_num']
grid = []
for block_num in full_df['date_block_num'].unique():
    cur_shops = full_df.loc[full_df['date_block_num'] == block_num, 'shop_id'].unique()
    cur_items = full_df.loc[full_df['date_block_num'] == block_num, 'item_id'].unique()
    grid.append(np.array(list(product(*[cur_shops, cur_items, [block_num]])), dtype='int32'))

grid = pd.DataFrame(np.vstack(grid), columns=index_cols, dtype=np.int32)

full_df = grid.merge(full_df, how='left', on=index_cols).fillna(0)

# %%
# for dbn in range(0, 34):
#     # create pair in (shop_id, item_id)
#     unique_shop_id = full_df[full_df['date_block_num'] == dbn]['shop_id'].copy().drop_duplicates()
#     unique_item_id = full_df[full_df['date_block_num'] == dbn]['item_id'].copy().drop_duplicates()
#     m_index = pd.MultiIndex.from_product([unique_shop_id, unique_item_id], names=['shop_id', 'item_id'])
#     val_df = pd.DataFrame([], index=m_index).reset_index()
#     val_df['ID'] = 0
#     val_df['date_block_num'] = dbn
# #     # distinguish origin train data
# #     val_df['ds_type'] = 'add_val'
#     # remove pair (shop_id, item_id) exists in full_df
#     origin_33_df = full_df[full_df['date_block_num'] == dbn][['item_id', 'shop_id', 'item_cnt_month']]
#     val_df = val_df.merge(origin_33_df, how='left', on=['item_id', 'shop_id'])
#     val_df = val_df[val_df.item_cnt_month.isnull()]
#     # no item_count then fill 0
#     val_df['item_cnt_month'] = 0

#     # merge to full_df
#     full_df = pd.concat([full_df, val_df])

# %%
full_df = full_df.sort_values(['date_block_num', 'shop_id', 'item_id'])

# %% [markdown]
# ## Features

# %%
feature_columns = []

def add_features(features):
    if not isinstance(features, list):
        features = [features]
    global feature_columns
    feature_columns.extend([f for f in features if f not in feature_columns])
    
def remove_features(features):
    if not isinstance(features, list):
        features = [features]
    global feature_columns
    feature_columns = [f for f in feature_columns if f not in features]

# %% [markdown]
# **shop_id, item_id**

# %%
# add_features(['shop_id', 'item_id'])

# %% [markdown]
# **datetime info**

# %%
full_df['dt_year'] = full_df['date_block_num'] // 12 + 2013
full_df['dt_month'] = full_df['date_block_num'] % 12 + 1
add_features(['dt_year', 'dt_month'])

# %% [markdown]
# **item category**

# %%
item_cate_df['item_cate_part1'] = item_cate_df['item_category_name'].map(lambda x: x.split('-')[0].strip())

# %%
le_model = preprocessing.LabelEncoder()
item_cate_df['item_cate_part1_id'] = le_model.fit_transform(item_cate_df['item_cate_part1'])

# %%
item_df = item_df.merge(item_cate_df, how='left', on='item_category_id')

# %% [markdown]
# **item_df**

# %%
# tfidf item_name
tfidf_model = TfidfVectorizer(max_df=0.95, min_df=3)
tfidf_res = tfidf_model.fit_transform(item_df['item_name'])

# decomposition
dcp_num = 5
dcp_model = TruncatedSVD(dcp_num)
dcp_tfidf_res = dcp_model.fit_transform(tfidf_res)

# add to item_df
item_name_tfidf_dcp_feats = ['item_name_tfidf_dcp_%d'%i for i in range(dcp_num)]
item_df[item_name_tfidf_dcp_feats] = pd.DataFrame(dcp_tfidf_res)

# %%
# item_name's words count
item_df['item_name_words_count'] = item_df['item_name'].map(lambda x: len(x.split(' ')))

# %%
# add to full_df
full_df = full_df.merge(item_df, how='left', on='item_id')

# add feautures
add_features(item_name_tfidf_dcp_feats + ['item_category_id', 'item_cate_part1_id', 'item_name_words_count'])

# %%
sales_df = sales_df.merge(item_df, how='left', on='item_id')

# %% [markdown]
# **mean encoding**

# %%
# global_mean = full_df[full_df['date_block_num'] < 34]['item_cnt_month'].mean()

# def get_aggragation_feature(df, groupby_cols, agg_col, fillna_value):
#     gb = df.groupby(groupby_cols)[agg_col]
#     fname_fmt = '-'.join(groupby_cols+[agg_col]) + ':%s'
#     agg_df = pd.DataFrame({
#             fname_fmt%'mean': gb.mean(),
# #             fname_fmt%'median': gb.median(),
# #             fname_fmt%'max': gb.max(),
# #             fname_fmt%'min': gb.min(),
#         })
    
#     new_df = df.join(agg_df, on=groupby_cols).fillna(fillna_value)
#     return new_df, agg_df.columns.tolist()

# groupby_cols_list = [
#     ['shop_id', 'item_id'],
#     ['shop_id'],
#     ['item_id'],
# #     ['date_block_num'],
# #     ['dt_year'],
# #     ['dt_month'],
# #     ['item_category_id'],
# ]
# for groupby_cols in groupby_cols_list:
#     full_df, new_feats = get_aggragation_feature(full_df, groupby_cols, 'item_cnt_month', global_mean)
#     add_features(new_feats)

# %%
global_mean = full_df[full_df['date_block_num'] < 34]['item_cnt_month'].mean()

mean_encoding_cols_list = [
    ['shop_id', 'item_id'],
    ['shop_id'],
    ['item_id'],
#     ['item_category_id'],
#     ['shop_id', 'item_category_id'],
#     ['item_cate_part1_id'],
#     ['shop_id', 'item_cate_part1_id'],
]
get_mean_encoding_feat_name = lambda cols: 'mean_encoding-' + '-'.join(cols)

for cols in mean_encoding_cols_list:
    full_df[get_mean_encoding_feat_name(cols)] = np.nan
    add_features(get_mean_encoding_feat_name(cols))

kf = KFold(5, shuffle=True, random_state=20180717)
for trn_idx, val_idx in kf.split(full_df['item_cnt_month'].values):
    trn_df, val_df = full_df.iloc[trn_idx].copy(), full_df.iloc[val_idx].copy()
    for cols in mean_encoding_cols_list:
        feat_name = get_mean_encoding_feat_name(cols)
        mean_map = trn_df.groupby(cols)['item_cnt_month'].mean()
        val_df[feat_name] = val_df[cols].join(mean_map, how='left', on=cols)['item_cnt_month']
    full_df.iloc[val_idx] = val_df
full_df.fillna(global_mean, inplace=True)

# %% [markdown]
# **lag features**

# %%
# 获取当月的一些数据（然后进行lag）
cur_month_cols_list = [
    ['shop_id'],
    ['item_id'],
    ['shop_id', 'item_id'],
    ['item_category_id'],
    ['shop_id', 'item_category_id'],
    ['item_cate_part1_id'],
    ['shop_id', 'item_cate_part1_id'],
]
cur_month_feats = []
for cols in cur_month_cols_list:
    print(cols)
    gb = sales_df.groupby(['date_block_num'] + cols) \
        .agg({'item_cnt_day': 'sum', 'item_price': 'mean'}) \
        .rename(columns={'item_cnt_day': 'target-' + '-'.join(cols),
                         'item_price': 'item_price-' + '-'.join(cols)})
    cur_month_feats += ['target-' + '-'.join(cols), 'item_price-' + '-'.join(cols)]
    full_df = full_df.join(gb, how='left', on=['date_block_num'] + cols).fillna(0)
# Out:
# ['shop_id']
# ['item_id']
# ['shop_id', 'item_id']
# ['item_category_id']
# ['shop_id', 'item_category_id']
# ['item_cate_part1_id']
# ['shop_id', 'item_cate_part1_id']

# %%
shift_range = [1,2,3,6,12]
shift_features = cur_month_feats

for shift_month in shift_range:
    print(shift_month)
    tmp_df = full_df[['shop_id', 'item_id', 'date_block_num'] + shift_features].copy()
    tmp_df['date_block_num'] = tmp_df['date_block_num'] + shift_month
    for f in shift_features:
        new_f = f + '_lag_' + str(shift_month)
        tmp_df = tmp_df.rename(columns={f: new_f})
        add_features(new_f)
    full_df = full_df.merge(tmp_df, how='left', on=['shop_id', 'item_id', 'date_block_num']).fillna(0)
# Out:
# 1
# 2
# 3
# 6
# 12

# %%
# remove 2013
full_df = full_df[full_df['date_block_num'] > 12]

# %% [markdown]
# **show all features**

# %%
feature_columns
# Out:
# ['dt_year',
#  'dt_month',
#  'item_name_tfidf_dcp_0',
#  'item_name_tfidf_dcp_1',
#  'item_name_tfidf_dcp_2',
#  'item_name_tfidf_dcp_3',
#  'item_name_tfidf_dcp_4',
#  'item_category_id',
#  'item_cate_part1_id',
#  'item_name_words_count',
#  'mean_encoding-shop_id-item_id',
#  'mean_encoding-shop_id',
#  'mean_encoding-item_id',
#  'target-shop_id_lag_1',
#  'item_price-shop_id_lag_1',
#  'target-item_id_lag_1',
#  'item_price-item_id_lag_1',
#  'target-shop_id-item_id_lag_1',
#  'item_price-shop_id-item_id_lag_1',
#  'target-item_category_id_lag_1',
#  'item_price-item_category_id_lag_1',
#  'target-shop_id-item_category_id_lag_1',
#  'item_price-shop_id-item_category_id_lag_1',
#  'target-item_cate_part1_id_lag_1',
#  'item_price-item_cate_part1_id_lag_1',
#  'target-shop_id-item_cate_part1_id_lag_1',
#  'item_price-shop_id-item_cate_part1_id_lag_1',
#  'target-shop_id_lag_2',
#  'item_price-shop_id_lag_2',
#  'target-item_id_lag_2',
#  'item_price-item_id_lag_2',
#  'target-shop_id-item_id_lag_2',
#  'item_price-shop_id-item_id_lag_2',
#  'target-item_category_id_lag_2',
#  'item_price-item_category_id_lag_2',
#  'target-shop_id-item_category_id_lag_2',
#  'item_price-shop_id-item_category_id_lag_2',
#  'target-item_cate_part1_id_lag_2',
#  'item_price-item_cate_part1_id_lag_2',
#  'target-shop_id-item_cate_part1_id_lag_2',
#  'item_price-shop_id-item_cate_part1_id_lag_2',
#  'target-shop_id_lag_3',
#  'item_price-shop_id_lag_3',
#  'target-item_id_lag_3',
#  'item_price-item_id_lag_3',
#  'target-shop_id-item_id_lag_3',
#  'item_price-shop_id-item_id_lag_3',
#  'target-item_category_id_lag_3',
#  'item_price-item_category_id_lag_3',
#  'target-shop_id-item_category_id_lag_3',
#  'item_price-shop_id-item_category_id_lag_3',
#  'target-item_cate_part1_id_lag_3',
#  'item_price-item_cate_part1_id_lag_3',
#  'target-shop_id-item_cate_part1_id_lag_3',
#  'item_price-shop_id-item_cate_part1_id_lag_3',
#  'target-shop_id_lag_6',
#  'item_price-shop_id_lag_6',
#  'target-item_id_lag_6',
#  'item_price-item_id_lag_6',
#  'target-shop_id-item_id_lag_6',
#  'item_price-shop_id-item_id_lag_6',
#  'target-item_category_id_lag_6',
#  'item_price-item_category_id_lag_6',
#  'target-shop_id-item_category_id_lag_6',
#  'item_price-shop_id-item_category_id_lag_6',
#  'target-item_cate_part1_id_lag_6',
#  'item_price-item_cate_part1_id_lag_6',
#  'target-shop_id-item_cate_part1_id_lag_6',
#  'item_price-shop_id-item_cate_part1_id_lag_6',
#  'target-shop_id_lag_12',
#  'item_price-shop_id_lag_12',
#  'target-item_id_lag_12',
#  'item_price-item_id_lag_12',
#  'target-shop_id-item_id_lag_12',
#  'item_price-shop_id-item_id_lag_12',
#  'target-item_category_id_lag_12',
#  'item_price-item_category_id_lag_12',
#  'target-shop_id-item_category_id_lag_12',
#  'item_price-shop_id-item_category_id_lag_12',
#  'target-item_cate_part1_id_lag_12',
#  'item_price-item_cate_part1_id_lag_12',
#  'target-shop_id-item_cate_part1_id_lag_12',
#  'item_price-shop_id-item_cate_part1_id_lag_12']

# %%
full_df
# Out:
#           shop_id  item_id  date_block_num        ID  item_cnt_month  dt_year  \
# 4836102         2       30              13       0.0             0.0     2014
# 4836103         2       31              13       0.0             0.0     2014
# 4836104         2       32              13       0.0             0.0     2014
# 4836105         2       33              13       0.0             0.0     2014
# 4836106         2       34              13       0.0             0.0     2014
# 4836107         2       36              13       0.0             0.0     2014
# 4836108         2       37              13       0.0             0.0     2014
# 4836109          2    100 Best classical melodies (mp3-CD) (Digipack)
# 4836110          2     100 Best romantic melodies (mp3-CD) (Digipack)
# 4836111          2  100 лучших мелодий против стресса (mp3-CD) (CD...
# 4836112          2   100 лучших народных песен (mp3-CD) (CD-Digipack)
# 4836113          2   100 лучших произведений Баха (mp3-CD) (Digipack)
# 4836114          2  100 лучших произведений Вивальди (mp3-CD) (CD-...
# 4836115          2  100 лучших произведений Моцарта (mp3-CD) (Digi...
# 4836116          2  100 лучших произведений классики (mp3-CD) (Dig...
# 4836117          2  100 лучших произведений фортепианной музыки (m...
# 4836118          2  100 лучших русских романсов (mp3-CD) (CD-Digip...
# 4836119          2      100 любимых маленьких сказок (mp3-CD) (Jewel)
# 4836120          2  100 любимых песен. Александра Пахмутова (подар...
# 4836121          2  100 пудов из мультхитов (подар. уп.) (mp3-CD) ...
# 4836122          2          100 шедевров классики (mp3-CD) (Digipack)
# 4836123          2  101 ДАЛМАТИНЕЦ 2:ПРИКЛЮЧЕНИЯ ПАТЧА В ЛОНДОНЕ (BD)
# 4836124          2                       11 ДРУЗЕЙ ОУШЕНА WB (регион)
# 4836125          2                       12 ДРУЗЕЙ ОУШЕНА WB (регион)
# 4836126          2                                         12 МЕСЯЦЕВ
# 4836127          2                          12 РОЖДЕСТВЕНСКИХ ЖЕЛАНИЙ
# 4836128          2                       13 ДРУЗЕЙ ОУШЕНА WB (регион)
# 4836129          2  15 знаменитых сказок  Детям от 0 до 3 лет (mp3...
# 4836130          2                  1812. ЭНЦИКЛОПЕДИЯ ВОЙНЫ (регион)
# 4836131          2                        1812: УЛАНСКАЯ БАЛЛАДА (BD)
# ...            ...                                                ...
# 11128020        11                                       ЭКИПАЖ (rem)
# 11128021        11                                ЭЛВИН И БУРУНДУКИ 2
# 11128022        11                                       ЭМПАЙР СТЭЙТ
# 11128023        11                      ЭПИДЕМИЯ  Сокровище Энии  2LP
# 11128024        11                                    ЭПИК (3D BD+BD)
# 11128025        11                                          ЭПИК (BD)
# 11128026        11                           ЭТА-ДУРАЦКАЯ-ЛЮБОВЬ (BD)
# 11128027        11                       ЭТА-ДУРАЦКАЯ-ЛЮБОВЬ (регион)
# 11128028        11                               ЭТОТ НЕЛОВКИЙ МОМЕНТ
# 11128029        11                  Элемент питания DURACELL LR03-BC2
# 11128030        11                  Элемент питания DURACELL LR06-BC2
# 11128031        11          Элемент питания DURACELL TURBO LR 03 2*BL
# 11128032        11            Элемент питания DURACELL TURBO LR6 2*BL
# 11128033        11                        Энциклопедия Adventure Time
# 11128034        11           Энциклопедия Dragon Age Мир Тедаса Том 1
# 11128035        11                          Энциклопедия Мир Ведьмака
# 11128036        11                           Ю-ПИТЕР  Гудгора (фирм.)
# 11128037        11  ЮГО-ЗАПАДНАЯ АМЕРИКА: ОТ ДОЛИНЫ СМЕРТИ ДО ВЕЛИ...
# 11128038        11  ЮЖНЫЕ МОРЯ: АТОЛЛ БИКИНИ И МАРШАЛЛОВЫ ОСТРОВА ...
# 11128039        11  Юмор и сатира  1  Рассказы русских писателей  ...
# 11128040        11                   Я ЛЮБЛЮ ТЕБЯ, ФИЛЛИП МОРРИС (BD)
# 11128041        11                                           Я, РОБОТ
# 11128042        11                                   Я, РОБОТ (3D BD)
# 11128043        11                               Я, ФРАНКЕНШТЕЙН (BD)
# 11128044        11                                  ЯВЛЕНИЕ 2012 (BD)
# 11128045        11                                             ЯРОСТЬ
# 11128046        11                                   ЯРОСТЬ ( регион)
# 11128047        11                                        ЯРОСТЬ (BD)
# 11128048        11    Язык запросов 1С:Предприятия  [Цифровая версия]
# 11128049        11  Язык запросов 1С:Предприятия 8 (+CD). Хрустале...
#
#           item_category_id                   item_category_name  \
# 4836102                 40                           Кино - DVD
# 4836103                 37                       Кино - Blu-Ray
# 4836104                 40                           Кино - DVD
# 4836105                 37                       Кино - Blu-Ray
# 4836106                 40                           Кино - DVD
# 4836107                 37                       Кино - Blu-Ray
# 4836108                 40                           Кино - DVD
# 4836109                 57                         Музыка - MP3
# 4836110                 57                         Музыка - MP3
# 4836111                 57                         Музыка - MP3
# 4836112                 57                         Музыка - MP3
# 4836113                 57                         Музыка - MP3
# 4836114                 57                         Музыка - MP3
# 4836115                 57                         Музыка - MP3
# 4836116                 57                         Музыка - MP3
# 4836117                 57                         Музыка - MP3
# 4836118                 57                         Музыка - MP3
# 4836119                 43                   Книги - Аудиокниги
# 4836120                 57                         Музыка - MP3
# 4836121                 57                         Музыка - MP3
# 4836122                 57                         Музыка - MP3
# 4836123                 37                       Кино - Blu-Ray
# 4836124                 40                           Кино - DVD
# 4836125                 40                           Кино - DVD
# 4836126                 40                           Кино - DVD
# 4836127                 40                           Кино - DVD
# 4836128                 40                           Кино - DVD
# 4836129                 43                   Книги - Аудиокниги
# 4836130                 40                           Кино - DVD
# 4836131                 37                       Кино - Blu-Ray
# ...                    ...                                  ...
# 11128020                40                           Кино - DVD
# 11128021                40                           Кино - DVD
# 11128022                40                           Кино - DVD
# 11128023                58                       Музыка - Винил
# 11128024                38                    Кино - Blu-Ray 3D
# 11128025                37                       Кино - Blu-Ray
# 11128026                37                       Кино - Blu-Ray
# 11128027                40                           Кино - DVD
# 11128028                40                           Кино - DVD
# 11128029                83                     Элементы питания
# 11128030                83                     Элементы питания
# 11128031                83                     Элементы питания
# 11128032                83                     Элементы питания
# 11128033                42        Книги - Артбуки, энциклопедии
# 11128034                42        Книги - Артбуки, энциклопедии
# 11128035                42        Книги - Артбуки, энциклопедии
# 11128036                55  Музыка - CD локального производства
# 11128037                38                    Кино - Blu-Ray 3D
# 11128038                38                    Кино - Blu-Ray 3D
# 11128039                43                   Книги - Аудиокниги
# 11128040                37                       Кино - Blu-Ray
# 11128041                40                           Кино - DVD
# 11128042                38                    Кино - Blu-Ray 3D
# 11128043                37                       Кино - Blu-Ray
# 11128044                37                       Кино - Blu-Ray
# 11128045                40                           Кино - DVD
# 11128046                40                           Кино - DVD
# 11128047                37                       Кино - Blu-Ray
# 11128048                54                        Книги - Цифра
# 11128049                49    Книги - Методические материалы 1С
#
#                               ...                       \
# 4836102                       ...
# 4836103                       ...
# 4836104                       ...
# 4836105                       ...
# 4836106                       ...
# 4836107                       ...
# 4836108                       ...
# 4836109                       ...
# 4836110                       ...
# 4836111                       ...
# 4836112                       ...
# 4836113                       ...
# 4836114                       ...
# 4836115                       ...
# 4836116                       ...
# 4836117                       ...
# 4836118                       ...
# 4836119                       ...
# 4836120                       ...
# 4836121                       ...
# 11128035                                       0.0
# 11128036                                       0.0
# 11128037                                     267.0
# 11128038                                     267.0
# 11128039                                       3.0
# 11128040                                       0.0
# 11128041                                       0.0
# 11128042                                     267.0
# 11128043                                       0.0
# 11128044                                       0.0
# 11128045                                       0.0
# 11128046                                       0.0
# 11128047                                       0.0
# 11128048                                       3.0
# 11128049                                       3.0
#
#           item_price-shop_id-item_cate_part1_id_lag_12
# 4836102                                     561.128205
# 4836103                                     561.128205
# 4836104                                     561.128205
# 4836105                                     561.128205
# 4836106                                     561.128205
# 4836107                                     561.128205
# 4836108                                       0.000000
# 4836109                                     249.000000
# 4836110                                     249.000000
# 4836111                                     249.000000
# 4836112                                     249.000000
# 4836113                                     249.000000
# 4836114                                     249.000000
# 4836115                                     249.000000
# 4836116                                     249.000000
# 4836117                                     249.000000
# 4836118                                     249.000000
# 4836119                                     349.800000
# 4836120                                     249.000000
# 4836121                                     249.000000
# 4836122                                     249.000000
# 4836123                                       0.000000
# 4836124                                     561.128205
# 4836125                                     561.128205
# 4836126                                       0.000000
# 4836127                                       0.000000
# 4836128                                     561.128205
# 4836129                                     349.800000
# 4836130                                     561.128205
# 4836131                                       0.000000
# ...                                                ...
# 11128020                                      0.000000
# 11128021                                      0.000000
# 11128022                                    374.147860
# 11128023                                      0.000000
# 11128024                                    374.147860
# 11128025                                    374.147860
# 11128026                                      0.000000
# 11128027                                      0.000000
# 11128028                                    374.147860
# 11128029                                     88.285714
# 11128030                                     88.285714
# 11128031                                     88.285714
# 11128032                                     88.285714
# 11128033                                      0.000000
# 11128034                                      0.000000
# 11128035                                      0.000000
# 11128036                                      0.000000
# 11128037                                    374.147860
# 11128038                                    374.147860
# 11128039                                    282.333333
# 11128040                                      0.000000
# 11128041                                      0.000000
# 11128042                                    374.147860
# 11128043                                      0.000000
# 11128044                                      0.000000
# 11128045                                      0.000000
# 11128046                                      0.000000
# 11128047                                      0.000000
# 11128048                                    282.333333
# 11128049                                    282.333333
#
# [6291948 rows x 105 columns]

# %% [markdown]
# **clip target**

# %%
full_df['item_cnt_month'] = full_df['item_cnt_month'].clip(0, 20)

# %% [markdown]
# ## Test features use lightgbm

# %%
dates = full_df['date_block_num'].copy()
XX_trn = full_df[dates <= 32][feature_columns]
yy_trn = full_df[dates <= 32][label_col]
XX_val = full_df[dates == 33][feature_columns]
yy_val = full_df[dates == 33][label_col]

# %%
trn_lgb = lgb.Dataset(XX_trn, yy_trn)
val_lgb = lgb.Dataset(XX_val, yy_val)

lgb_params = {
    'application': 'regression',
    'metric': 'rmse',
    'learning_rate': 0.1,
    'max_depth': 5,
    'num_leaves': 20,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.5,
    'bagging_freq': 1,
    'seed': 0,
}
train_round = 150

bst = lgb.train(lgb_params, trn_lgb, train_round, valid_sets=[trn_lgb, val_lgb], early_stopping_rounds=20)
# Out:
# [1]	training's rmse: 1.13606	valid_1's rmse: 1.10224
# Training until validation scores don't improve for 20 rounds.
# [2]	training's rmse: 1.09583	valid_1's rmse: 1.07735
# [3]	training's rmse: 1.05655	valid_1's rmse: 1.05479
# [4]	training's rmse: 1.02382	valid_1's rmse: 1.02619
# [5]	training's rmse: 0.995031	valid_1's rmse: 1.01123
# [6]	training's rmse: 0.970421	valid_1's rmse: 0.999928
# [7]	training's rmse: 0.949391	valid_1's rmse: 0.991009
# [8]	training's rmse: 0.93481	valid_1's rmse: 0.98277
# [9]	training's rmse: 0.919357	valid_1's rmse: 0.976922
# [10]	training's rmse: 0.905905	valid_1's rmse: 0.973544
# [11]	training's rmse: 0.89467	valid_1's rmse: 0.970501
# [12]	training's rmse: 0.885167	valid_1's rmse: 0.968221
# [13]	training's rmse: 0.876258	valid_1's rmse: 0.963248
# [14]	training's rmse: 0.868661	valid_1's rmse: 0.9604
# [15]	training's rmse: 0.862444	valid_1's rmse: 0.958847
# [16]	training's rmse: 0.856462	valid_1's rmse: 0.955534
# [17]	training's rmse: 0.851652	valid_1's rmse: 0.953287
# [18]	training's rmse: 0.847593	valid_1's rmse: 0.952773
# [19]	training's rmse: 0.842874	valid_1's rmse: 0.947733
# [20]	training's rmse: 0.839175	valid_1's rmse: 0.943377
# [21]	training's rmse: 0.835494	valid_1's rmse: 0.941151
# [22]	training's rmse: 0.83272	valid_1's rmse: 0.939631
# [23]	training's rmse: 0.829924	valid_1's rmse: 0.937083
# [24]	training's rmse: 0.827884	valid_1's rmse: 0.937161
# [25]	training's rmse: 0.825968	valid_1's rmse: 0.934381
# [26]	training's rmse: 0.824405	valid_1's rmse: 0.93393
# [27]	training's rmse: 0.822657	valid_1's rmse: 0.93322
# [28]	training's rmse: 0.821241	valid_1's rmse: 0.928888
# [29]	training's rmse: 0.820095	valid_1's rmse: 0.928997
# [30]	training's rmse: 0.817965	valid_1's rmse: 0.92796
# [31]	training's rmse: 0.816797	valid_1's rmse: 0.927923
# [32]	training's rmse: 0.815065	valid_1's rmse: 0.926328
# [33]	training's rmse: 0.814092	valid_1's rmse: 0.926431
# [34]	training's rmse: 0.81228	valid_1's rmse: 0.921595
# [35]	training's rmse: 0.81146	valid_1's rmse: 0.921171
# [36]	training's rmse: 0.809709	valid_1's rmse: 0.916571
# [37]	training's rmse: 0.808715	valid_1's rmse: 0.916465
# [38]	training's rmse: 0.807013	valid_1's rmse: 0.914497
# [39]	training's rmse: 0.805969	valid_1's rmse: 0.911486
# [40]	training's rmse: 0.804751	valid_1's rmse: 0.910483
# [41]	training's rmse: 0.803378	valid_1's rmse: 0.908716
# [42]	training's rmse: 0.802115	valid_1's rmse: 0.907213
# [43]	training's rmse: 0.801389	valid_1's rmse: 0.906862
# [44]	training's rmse: 0.80055	valid_1's rmse: 0.906366
# [45]	training's rmse: 0.799202	valid_1's rmse: 0.906309
# [46]	training's rmse: 0.798637	valid_1's rmse: 0.906133
# [47]	training's rmse: 0.7978	valid_1's rmse: 0.905535
# [48]	training's rmse: 0.797052	valid_1's rmse: 0.904611
# [49]	training's rmse: 0.796368	valid_1's rmse: 0.904596
# [50]	training's rmse: 0.795312	valid_1's rmse: 0.90288
# [51]	training's rmse: 0.794567	valid_1's rmse: 0.902681
# [52]	training's rmse: 0.793151	valid_1's rmse: 0.901983
# [53]	training's rmse: 0.792033	valid_1's rmse: 0.901848
# [54]	training's rmse: 0.791388	valid_1's rmse: 0.90144
# [55]	training's rmse: 0.79071	valid_1's rmse: 0.901403
# [56]	training's rmse: 0.790287	valid_1's rmse: 0.90111
# [57]	training's rmse: 0.789377	valid_1's rmse: 0.900332
# [58]	training's rmse: 0.788893	valid_1's rmse: 0.900235
# [59]	training's rmse: 0.788351	valid_1's rmse: 0.900051
# [60]	training's rmse: 0.788111	valid_1's rmse: 0.899821
# [61]	training's rmse: 0.787464	valid_1's rmse: 0.899583
# [62]	training's rmse: 0.787067	valid_1's rmse: 0.89931
# [63]	training's rmse: 0.786826	valid_1's rmse: 0.899108
# [64]	training's rmse: 0.786237	valid_1's rmse: 0.898889
# [65]	training's rmse: 0.785764	valid_1's rmse: 0.898479
# [66]	training's rmse: 0.785361	valid_1's rmse: 0.899273
# [67]	training's rmse: 0.784891	valid_1's rmse: 0.898697
# [68]	training's rmse: 0.784503	valid_1's rmse: 0.898993
# [69]	training's rmse: 0.784073	valid_1's rmse: 0.89909
# [70]	training's rmse: 0.783661	valid_1's rmse: 0.898527
# [71]	training's rmse: 0.783246	valid_1's rmse: 0.898874
# [72]	training's rmse: 0.782845	valid_1's rmse: 0.899003
# [73]	training's rmse: 0.782343	valid_1's rmse: 0.899451
# [74]	training's rmse: 0.781824	valid_1's rmse: 0.899495
# [75]	training's rmse: 0.781464	valid_1's rmse: 0.899088
# [76]	training's rmse: 0.781188	valid_1's rmse: 0.89898
# [77]	training's rmse: 0.780788	valid_1's rmse: 0.89907
# [78]	training's rmse: 0.78042	valid_1's rmse: 0.8989
# [79]	training's rmse: 0.779655	valid_1's rmse: 0.898883
# [80]	training's rmse: 0.779447	valid_1's rmse: 0.898877
# [81]	training's rmse: 0.779054	valid_1's rmse: 0.89874
# [82]	training's rmse: 0.778661	valid_1's rmse: 0.898561
# [83]	training's rmse: 0.77782	valid_1's rmse: 0.897413
# [84]	training's rmse: 0.777287	valid_1's rmse: 0.893852
# [85]	training's rmse: 0.776907	valid_1's rmse: 0.893556
# [86]	training's rmse: 0.776576	valid_1's rmse: 0.893545
# [87]	training's rmse: 0.7763	valid_1's rmse: 0.893324
# [88]	training's rmse: 0.775957	valid_1's rmse: 0.893433
# [89]	training's rmse: 0.775256	valid_1's rmse: 0.893471
# [90]	training's rmse: 0.775003	valid_1's rmse: 0.893482
# [91]	training's rmse: 0.774758	valid_1's rmse: 0.893239
# [92]	training's rmse: 0.774079	valid_1's rmse: 0.892596
# [93]	training's rmse: 0.773776	valid_1's rmse: 0.892606
# [94]	training's rmse: 0.773475	valid_1's rmse: 0.892131
# [95]	training's rmse: 0.77312	valid_1's rmse: 0.891741
# [96]	training's rmse: 0.7728	valid_1's rmse: 0.891935
# [97]	training's rmse: 0.772577	valid_1's rmse: 0.891954
# [98]	training's rmse: 0.772273	valid_1's rmse: 0.891698
# [99]	training's rmse: 0.772004	valid_1's rmse: 0.89102
# [100]	training's rmse: 0.771786	valid_1's rmse: 0.890994
# [101]	training's rmse: 0.771589	valid_1's rmse: 0.890789
# [102]	training's rmse: 0.771379	valid_1's rmse: 0.89065
# [103]	training's rmse: 0.77109	valid_1's rmse: 0.89068
# [104]	training's rmse: 0.770977	valid_1's rmse: 0.890661
# [105]	training's rmse: 0.770431	valid_1's rmse: 0.889697
# [106]	training's rmse: 0.770203	valid_1's rmse: 0.889771
# [107]	training's rmse: 0.769997	valid_1's rmse: 0.88974
# [108]	training's rmse: 0.769748	valid_1's rmse: 0.889384
# [109]	training's rmse: 0.769544	valid_1's rmse: 0.889434
# [110]	training's rmse: 0.769259	valid_1's rmse: 0.888812
# [111]	training's rmse: 0.769068	valid_1's rmse: 0.888742
# [112]	training's rmse: 0.768779	valid_1's rmse: 0.888773
# [113]	training's rmse: 0.768454	valid_1's rmse: 0.888791
# [114]	training's rmse: 0.768202	valid_1's rmse: 0.888403
# [115]	training's rmse: 0.767959	valid_1's rmse: 0.8883
# [116]	training's rmse: 0.767593	valid_1's rmse: 0.887926
# [117]	training's rmse: 0.767426	valid_1's rmse: 0.887878
# [118]	training's rmse: 0.767021	valid_1's rmse: 0.887925
# [119]	training's rmse: 0.766729	valid_1's rmse: 0.887903
# [120]	training's rmse: 0.766471	valid_1's rmse: 0.887575
# [121]	training's rmse: 0.766035	valid_1's rmse: 0.887571
# [122]	training's rmse: 0.765929	valid_1's rmse: 0.887516
# [123]	training's rmse: 0.765766	valid_1's rmse: 0.887437
# [124]	training's rmse: 0.765256	valid_1's rmse: 0.887192
# [125]	training's rmse: 0.765034	valid_1's rmse: 0.88728
# [126]	training's rmse: 0.764765	valid_1's rmse: 0.886908
# [127]	training's rmse: 0.764579	valid_1's rmse: 0.886954
# [128]	training's rmse: 0.764444	valid_1's rmse: 0.886812
# [129]	training's rmse: 0.764305	valid_1's rmse: 0.886883
# [130]	training's rmse: 0.764134	valid_1's rmse: 0.886867
# [131]	training's rmse: 0.763422	valid_1's rmse: 0.887173
# [132]	training's rmse: 0.763026	valid_1's rmse: 0.88684
# [133]	training's rmse: 0.762794	valid_1's rmse: 0.886713
# [134]	training's rmse: 0.762669	valid_1's rmse: 0.886737
# [135]	training's rmse: 0.762261	valid_1's rmse: 0.886939
# [136]	training's rmse: 0.762124	valid_1's rmse: 0.886843
# [137]	training's rmse: 0.761571	valid_1's rmse: 0.886679
# [138]	training's rmse: 0.761421	valid_1's rmse: 0.886403
# [139]	training's rmse: 0.761264	valid_1's rmse: 0.886386
# [140]	training's rmse: 0.761099	valid_1's rmse: 0.886599
# [141]	training's rmse: 0.760726	valid_1's rmse: 0.886625
# [142]	training's rmse: 0.760303	valid_1's rmse: 0.886016
# [143]	training's rmse: 0.760108	valid_1's rmse: 0.885964
# [144]	training's rmse: 0.760003	valid_1's rmse: 0.885965
# [145]	training's rmse: 0.759905	valid_1's rmse: 0.885966
# [146]	training's rmse: 0.759736	valid_1's rmse: 0.885756
# [147]	training's rmse: 0.759224	valid_1's rmse: 0.885652
# [148]	training's rmse: 0.759014	valid_1's rmse: 0.885587
# [149]	training's rmse: 0.75872	valid_1's rmse: 0.885298
# [150]	training's rmse: 0.758563	valid_1's rmse: 0.885263
# Did not meet early stopping. Best iteration is:
# [150]	training's rmse: 0.758563	valid_1's rmse: 0.885263

# %%
imp_df = pd.DataFrame([bst.feature_importance()], columns=feature_columns, index=['importance']).T.sort_values(by='importance', ascending=False)
imp_df
# Out:
#                                               importance
# target-item_id_lag_1                                 253
# mean_encoding-item_id                                190
# target-shop_id-item_id_lag_1                         188
# mean_encoding-shop_id-item_id                        186
# dt_month                                             105
# mean_encoding-shop_id                                 78
# target-shop_id-item_id_lag_2                          77
# target-item_id_lag_2                                  74
# target-shop_id-item_category_id_lag_1                 72
# item_name_tfidf_dcp_4                                 70
# target-item_category_id_lag_1                         65
# item_category_id                                      59
# target-item_cate_part1_id_lag_1                       55
# target-item_cate_part1_id_lag_2                       53
# item_name_tfidf_dcp_3                                 51
# item_price-shop_id-item_id_lag_1                      50
# item_price-item_id_lag_1                              46
# item_price-item_cate_part1_id_lag_1                   46
# target-shop_id_lag_2                                  45
# target-item_category_id_lag_2                         42
# target-item_id_lag_3                                  42
# target-shop_id-item_category_id_lag_2                 38
# dt_year                                               38
# item_price-item_category_id_lag_1                     38
# item_name_tfidf_dcp_1                                 37
# item_price-item_cate_part1_id_lag_2                   36
# target-shop_id-item_id_lag_3                          35
# target-shop_id_lag_1                                  35
# target-item_id_lag_12                                 32
# item_name_tfidf_dcp_2                                 31
# ...                                                  ...
# item_price-item_cate_part1_id_lag_3                   15
# item_price-item_id_lag_6                              14
# target-item_cate_part1_id_lag_12                      14
# item_price-item_cate_part1_id_lag_12                  13
# item_price-shop_id_lag_2                              13
# target-item_category_id_lag_12                        12
# target-shop_id-item_category_id_lag_3                 11
# item_price-item_id_lag_12                             11
# item_price-shop_id-item_category_id_lag_2             10
# item_price-shop_id-item_category_id_lag_1             10
# item_price-item_category_id_lag_12                     9
# item_price-shop_id_lag_3                               9
# item_price-shop_id_lag_12                              9
# target-shop_id-item_cate_part1_id_lag_6                8
# item_price-shop_id-item_cate_part1_id_lag_1            7
# item_price-item_cate_part1_id_lag_6                    7
# item_price-shop_id-item_cate_part1_id_lag_6            6
# item_cate_part1_id                                     5
# item_price-shop_id-item_category_id_lag_3              4
# target-shop_id-item_id_lag_12                          4
# target-shop_id-item_cate_part1_id_lag_3                4
# item_price-shop_id-item_id_lag_6                       4
# target-shop_id-item_cate_part1_id_lag_12               3
# target-shop_id-item_category_id_lag_6                  3
# target-shop_id-item_category_id_lag_12                 3
# item_price-shop_id-item_cate_part1_id_lag_12           2
# item_price-shop_id-item_id_lag_12                      2
# item_price-shop_id-item_cate_part1_id_lag_3            2
# item_price-shop_id-item_category_id_lag_12             0
# item_price-shop_id-item_category_id_lag_6              0
#
# [83 rows x 1 columns]

# %% [markdown]
# ## Save

# %%
# %%time
features_save(full_df, feature_columns)
# Out:
# CPU times: user 13min 58s, sys: 42.1 s, total: 14min 40s
# Wall time: 15min 6s
